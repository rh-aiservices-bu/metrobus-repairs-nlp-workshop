# %% [markdown]
# ## Flask
# Our API will be served directly from our container using Flask, a popular Python Web Server.
# The Flask application, which will call our prediction function, is defined in the `wsgi.py` file.

# %% [markdown]
# As always, we'll first run some imports to make sure all our requirements are there:

# %%
import sys
# !{sys.executable} -m pip install -r requirements.txt
# Out:
# Collecting Flask
#   Downloading Flask-2.0.1-py3-none-any.whl (94 kB)
#      |████████████████████████████████| 94 kB 33.1 MB/s eta 0:00:01
# Collecting gunicorn
#   Downloading gunicorn-20.1.0-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 23.7 MB/s eta 0:00:01
# Collecting opencv-python-headless==4.5.*
#   Downloading opencv_python_headless-4.5.3.56-cp38-cp38-manylinux2014_x86_64.whl (37.1 MB)
#      |████████████████████████████████| 37.1 MB 81.6 MB/s eta 0:00:01
# Collecting keras==2.4.*
#   Downloading Keras-2.4.3-py2.py3-none-any.whl (36 kB)
# Requirement already satisfied: tensorflow-gpu==2.4.1 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 5)) (2.4.1)
# Collecting scikit-image==0.18.1
#   Downloading scikit_image-0.18.1-cp38-cp38-manylinux1_x86_64.whl (30.2 MB)
#      |████████████████████████████████| 30.2 MB 35.2 MB/s eta 0:00:01
# Requirement already satisfied: scikit-learn==0.24.1 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 7)) (0.24.1)
# Requirement already satisfied: h5py==2.10.0 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 8)) (2.10.0)
# Collecting spacy==3.1.0
#   Downloading spacy-3.1.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.5 MB)
#      |████████████████████████████████| 6.5 MB 32.6 MB/s eta 0:00:01
# Requirement already satisfied: statsmodels==0.10.2 in /opt/app-root/lib/python3.8/site-packages (from -r requirements.txt (line 10)) (0.10.2)
# Requirement already satisfied: numpy>=1.17.3 in /opt/app-root/lib/python3.8/site-packages (from opencv-python-headless==4.5.*->-r requirements.txt (line 3)) (1.19.2)
# Requirement already satisfied: scipy>=0.14 in /opt/app-root/lib/python3.8/site-packages (from keras==2.4.*->-r requirements.txt (line 4)) (1.6.2)
# Requirement already satisfied: pyyaml in /opt/app-root/lib/python3.8/site-packages (from keras==2.4.*->-r requirements.txt (line 4)) (5.4.1)
# Requirement already satisfied: six~=1.15.0 in /opt/app-root/lib/python3.8/site-packages (from tensorflow-gpu==2.4.1->-r requirements.txt (line 5)) (1.15.0)
# Requirement already satisfied: gast==0.3.3 in /opt/app-root/lib/python3.8/site-packages (from tensorflow-gpu==2.4.1->-r requirements.txt (line 5)) (0.3.3)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /opt/app-root/lib/python3.8/site-packages (from tensorflow-gpu==2.4.1->-r requirements.txt (line 5)) (1.1.2)
# Requirement already satisfied: google-pasta~=0.2 in /opt/app-root/lib/python3.8/site-packages (from tensorflow-gpu==2.4.1->-r requirements.txt (line 5)) (0.2.0)
# Requirement already satisfied: wheel~=0.35 in /opt/app-root/lib/python3.8/site-packages (from tensorflow-gpu==2.4.1->-r requirements.txt (line 5)) (0.36.2)
# Requirement already satisfied: protobuf>=3.9.2 in /opt/app-root/lib/python3.8/site-packages (from tensorflow-gpu==2.4.1->-r requirements.txt (line 5)) (3.17.3)
# Requirement already satisfied: tensorboard~=2.4 in /opt/app-root/lib/python3.8/site-packages (from tensorflow-gpu==2.4.1->-r requirements.txt (line 5)) (2.5.0)
# Requirement already satisfied: tensorflow-estimator<2.5.0,>=2.4.0 in /opt/app-root/lib/python3.8/site-packages (from tensorflow-gpu==2.4.1->-r requirements.txt (line 5)) (2.4.0)
# Requirement already satisfied: opt-einsum~=3.3.0 in /opt/app-root/lib/python3.8/site-packages (from tensorflow-gpu==2.4.1->-r requirements.txt (line 5)) (3.3.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in /opt/app-root/lib/python3.8/site-packages (from tensorflow-gpu==2.4.1->-r requirements.txt (line 5)) (3.7.4.3)
# Requirement already satisfied: wrapt~=1.12.1 in /opt/app-root/lib/python3.8/site-packages (from tensorflow-gpu==2.4.1->-r requirements.txt (line 5)) (1.12.1)
# Requirement already satisfied: grpcio~=1.32.0 in /opt/app-root/lib/python3.8/site-packages (from tensorflow-gpu==2.4.1->-r requirements.txt (line 5)) (1.32.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in /opt/app-root/lib/python3.8/site-packages (from tensorflow-gpu==2.4.1->-r requirements.txt (line 5)) (1.12)
# Requirement already satisfied: termcolor~=1.1.0 in /opt/app-root/lib/python3.8/site-packages (from tensorflow-gpu==2.4.1->-r requirements.txt (line 5)) (1.1.0)
# Requirement already satisfied: astunparse~=1.6.3 in /opt/app-root/lib/python3.8/site-packages (from tensorflow-gpu==2.4.1->-r requirements.txt (line 5)) (1.6.3)
# Requirement already satisfied: absl-py~=0.10 in /opt/app-root/lib/python3.8/site-packages (from tensorflow-gpu==2.4.1->-r requirements.txt (line 5)) (0.13.0)
# Requirement already satisfied: networkx>=2.0 in /opt/app-root/lib/python3.8/site-packages (from scikit-image==0.18.1->-r requirements.txt (line 6)) (2.5.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /opt/app-root/lib/python3.8/site-packages (from scikit-image==0.18.1->-r requirements.txt (line 6)) (2021.7.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in /opt/app-root/lib/python3.8/site-packages (from scikit-image==0.18.1->-r requirements.txt (line 6)) (1.1.1)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,>=4.3.0 in /opt/app-root/lib/python3.8/site-packages (from scikit-image==0.18.1->-r requirements.txt (line 6)) (8.3.1)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.0 in /opt/app-root/lib/python3.8/site-packages (from scikit-image==0.18.1->-r requirements.txt (line 6)) (3.4.1)
# Requirement already satisfied: imageio>=2.3.0 in /opt/app-root/lib/python3.8/site-packages (from scikit-image==0.18.1->-r requirements.txt (line 6)) (2.9.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/app-root/lib/python3.8/site-packages (from scikit-learn==0.24.1->-r requirements.txt (line 7)) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in /opt/app-root/lib/python3.8/site-packages (from scikit-learn==0.24.1->-r requirements.txt (line 7)) (1.0.1)
# Collecting srsly<3.0.0,>=2.4.1
#   Downloading srsly-2.4.1-cp38-cp38-manylinux2014_x86_64.whl (458 kB)
#      |████████████████████████████████| 458 kB 108.9 MB/s eta 0:00:01
# Collecting catalogue<2.1.0,>=2.0.4
#   Downloading catalogue-2.0.4-py3-none-any.whl (16 kB)
# Collecting pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4
#   Downloading pydantic-1.8.2-cp38-cp38-manylinux2014_x86_64.whl (13.7 MB)
#      |████████████████████████████████| 13.7 MB 90.7 MB/s eta 0:00:01
# Collecting thinc<8.1.0,>=8.0.7
#   Downloading thinc-8.0.8-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (629 kB)
#      |████████████████████████████████| 629 kB 100.4 MB/s eta 0:00:01
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/app-root/lib/python3.8/site-packages (from spacy==3.1.0->-r requirements.txt (line 9)) (2.25.1)
# Requirement already satisfied: setuptools in /opt/app-root/lib/python3.8/site-packages (from spacy==3.1.0->-r requirements.txt (line 9)) (57.4.0)
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.5-cp38-cp38-manylinux2014_x86_64.whl (35 kB)
# Collecting typer<0.4.0,>=0.3.0
#   Downloading typer-0.3.2-py3-none-any.whl (21 kB)
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.5-cp38-cp38-manylinux2014_x86_64.whl (130 kB)
#      |████████████████████████████████| 130 kB 113.1 MB/s eta 0:00:01
# Collecting tqdm<5.0.0,>=4.38.0
#   Downloading tqdm-4.61.2-py2.py3-none-any.whl (76 kB)
#      |████████████████████████████████| 76 kB 94.6 MB/s  eta 0:00:01
# Requirement already satisfied: packaging>=20.0 in /opt/app-root/lib/python3.8/site-packages (from spacy==3.1.0->-r requirements.txt (line 9)) (21.0)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.5-cp38-cp38-manylinux2014_x86_64.whl (20 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.7
#   Downloading spacy_legacy-3.0.8-py2.py3-none-any.whl (14 kB)
# Collecting blis<0.8.0,>=0.4.0
#   Downloading blis-0.7.4-cp38-cp38-manylinux2014_x86_64.whl (9.8 MB)
#      |████████████████████████████████| 9.8 MB 97.4 MB/s eta 0:00:01
# Requirement already satisfied: jinja2 in /opt/app-root/lib/python3.8/site-packages (from spacy==3.1.0->-r requirements.txt (line 9)) (3.0.1)
# Collecting pathy>=0.3.5
#   Downloading pathy-0.6.0-py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 49.5 MB/s eta 0:00:01
# Collecting wasabi<1.1.0,>=0.8.1
#   Downloading wasabi-0.8.2-py3-none-any.whl (23 kB)
# Requirement already satisfied: patsy>=0.4.0 in /opt/app-root/lib/python3.8/site-packages (from statsmodels==0.10.2->-r requirements.txt (line 10)) (0.5.1)
# Requirement already satisfied: pandas>=0.19 in /opt/app-root/lib/python3.8/site-packages (from statsmodels==0.10.2->-r requirements.txt (line 10)) (1.2.4)
# Requirement already satisfied: Werkzeug>=2.0 in /opt/app-root/lib/python3.8/site-packages (from Flask->-r requirements.txt (line 1)) (2.0.1)
# Requirement already satisfied: click>=7.1.2 in /opt/app-root/lib/python3.8/site-packages (from Flask->-r requirements.txt (line 1)) (8.0.1)
# Collecting itsdangerous>=2.0
#   Downloading itsdangerous-2.0.1-py3-none-any.whl (18 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/app-root/lib/python3.8/site-packages (from jinja2->spacy==3.1.0->-r requirements.txt (line 9)) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/app-root/lib/python3.8/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image==0.18.1->-r requirements.txt (line 6)) (2.8.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/app-root/lib/python3.8/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image==0.18.1->-r requirements.txt (line 6)) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/app-root/lib/python3.8/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image==0.18.1->-r requirements.txt (line 6)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/app-root/lib/python3.8/site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image==0.18.1->-r requirements.txt (line 6)) (0.10.0)
# Requirement already satisfied: decorator<5,>=4.3 in /opt/app-root/lib/python3.8/site-packages (from networkx>=2.0->scikit-image==0.18.1->-r requirements.txt (line 6)) (4.4.2)
# Requirement already satisfied: pytz>=2017.3 in /opt/app-root/lib/python3.8/site-packages (from pandas>=0.19->statsmodels==0.10.2->-r requirements.txt (line 10)) (2021.1)
# Collecting smart-open<6.0.0,>=5.0.0
#   Downloading smart_open-5.1.0-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 85.0 MB/s eta 0:00:01
# Requirement already satisfied: certifi>=2017.4.17 in /opt/app-root/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy==3.1.0->-r requirements.txt (line 9)) (2021.5.30)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/app-root/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy==3.1.0->-r requirements.txt (line 9)) (1.26.6)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/app-root/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy==3.1.0->-r requirements.txt (line 9)) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /opt/app-root/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy==3.1.0->-r requirements.txt (line 9)) (2.10)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /opt/app-root/lib/python3.8/site-packages (from tensorboard~=2.4->tensorflow-gpu==2.4.1->-r requirements.txt (line 5)) (0.4.4)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /opt/app-root/lib/python3.8/site-packages (from tensorboard~=2.4->tensorflow-gpu==2.4.1->-r requirements.txt (line 5)) (0.6.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /opt/app-root/lib/python3.8/site-packages (from tensorboard~=2.4->tensorflow-gpu==2.4.1->-r requirements.txt (line 5)) (1.32.1)
# Requirement already satisfied: markdown>=2.6.8 in /opt/app-root/lib/python3.8/site-packages (from tensorboard~=2.4->tensorflow-gpu==2.4.1->-r requirements.txt (line 5)) (3.3.4)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /opt/app-root/lib/python3.8/site-packages (from tensorboard~=2.4->tensorflow-gpu==2.4.1->-r requirements.txt (line 5)) (1.8.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/app-root/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow-gpu==2.4.1->-r requirements.txt (line 5)) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/app-root/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow-gpu==2.4.1->-r requirements.txt (line 5)) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /opt/app-root/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow-gpu==2.4.1->-r requirements.txt (line 5)) (4.2.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/app-root/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow-gpu==2.4.1->-r requirements.txt (line 5)) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/app-root/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow-gpu==2.4.1->-r requirements.txt (line 5)) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/app-root/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow-gpu==2.4.1->-r requirements.txt (line 5)) (3.1.1)
# Collecting click>=7.1.2
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
#      |████████████████████████████████| 82 kB 55.5 MB/s  eta 0:00:01
# Installing collected packages: murmurhash, cymem, click, catalogue, wasabi, typer, srsly, smart-open, pydantic, preshed, blis, tqdm, thinc, spacy-legacy, pathy, itsdangerous, spacy, scikit-image, opencv-python-headless, keras, gunicorn, Flask
#   Attempting uninstall: click
#     Found existing installation: click 8.0.1
#     Uninstalling click-8.0.1:
#       Successfully uninstalled click-8.0.1
#   Attempting uninstall: scikit-image
#     Found existing installation: scikit-image 0.18.2
#     Uninstalling scikit-image-0.18.2:
#       Successfully uninstalled scikit-image-0.18.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thoth-python 0.15.6 requires beautifulsoup4==4.6.3, but you have beautifulsoup4 4.8.2 which is incompatible.
# Successfully installed Flask-2.0.1 blis-0.7.4 catalogue-2.0.4 click-7.1.2 cymem-2.0.5 gunicorn-20.1.0 itsdangerous-2.0.1 keras-2.4.3 murmurhash-1.0.5 opencv-python-headless-4.5.3.56 pathy-0.6.0 preshed-3.0.5 pydantic-1.8.2 scikit-image-0.18.1 smart-open-5.1.0 spacy-3.1.0 spacy-legacy-3.0.8 srsly-2.4.1 thinc-8.0.8 tqdm-4.61.2 typer-0.3.2 wasabi-0.8.2

# %% [markdown]
# Now that we have everything in place, we can launch the Flask application.
#
# (Please ignore the CUDA errors of warning if you don't have any GPU).
#
# This cell will be in a **permanent running state**. That's normal as the webserver process will keep running. When you are **finished** with the test you can just select the cell, and click on the **Stop button** (next to Run).

# %%
# !FLASK_ENV=development FLASK_APP=wsgi.py flask run
# Out:
#  * Serving Flask app 'wsgi.py' (lazy loading)
#  * Environment: development
#  * Debug mode: on
# 2021-07-28 20:32:22.895173: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-07-28 20:32:24.256457: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-07-28 20:32:24.256857: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2021-07-28 20:32:24.256879: W tensorflow/stream_executor/cuda/cuda_driver.cc:326] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-07-28 20:32:24.257038: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (jupyterhub-nb-adrezni): /proc/driver/nvidia/version does not exist
# 2021-07-28 20:32:24.257271: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-07-28 20:32:24.258896: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-07-28 20:32:24.323858: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2021-07-28 20:32:24.336272: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2500000000 Hz
# Epoch 1/2
# 23/23 [==============================] - 1s 27ms/step - loss: 0.9485 - accuracy: 0.5739 - val_loss: 0.5210 - val_accuracy: 0.9375
# Epoch 2/2
# 23/23 [==============================] - 0s 5ms/step - loss: 0.3934 - accuracy: 0.9772 - val_loss: 0.2334 - val_accuracy: 0.9750
# 7/7 [==============================] - 0s 905us/step - loss: 0.2170 - accuracy: 0.9850
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
#  * Restarting with stat
#  * Debugger is active!
#  * Debugger PIN: 144-592-317
# 2021-07-28 20:32:32.000226: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-07-28 20:32:33.458122: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-07-28 20:32:33.458370: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2021-07-28 20:32:33.458391: W tensorflow/stream_executor/cuda/cuda_driver.cc:326] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-07-28 20:32:33.458423: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (jupyterhub-nb-adrezni): /proc/driver/nvidia/version does not exist
# 2021-07-28 20:32:33.458622: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-07-28 20:32:33.460332: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-07-28 20:32:33.525294: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2021-07-28 20:32:33.525765: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2500000000 Hz
# Epoch 1/2
# 23/23 [==============================] - 1s 34ms/step - loss: 0.9375 - accuracy: 0.5574 - val_loss: 0.5326 - val_accuracy: 0.9375
# Epoch 2/2
# 23/23 [==============================] - 0s 5ms/step - loss: 0.4206 - accuracy: 0.9739 - val_loss: 0.2409 - val_accuracy: 0.9750
# 7/7 [==============================] - 0s 901us/step - loss: 0.2278 - accuracy: 0.9800
# 127.0.0.1 - - [28/Jul/2021 20:32:50] "GET /status HTTP/1.1" 200 -
# WARNING:tensorflow:Model was constructed with shape (None, 1000) for input KerasTensor(type_spec=TensorSpec(shape=(None, 1000), dtype=tf.float32, name='dense_input'), name='dense_input', description="created by layer 'dense_input'"), but it was called on an input with incompatible shape (None, 1, 1000).
# 127.0.0.1 - - [28/Jul/2021 20:32:54] "POST /predictions HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jul/2021 20:32:58] "POST /predictions HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jul/2021 20:44:47] "GET /status HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jul/2021 20:44:50] "POST /prediction HTTP/1.1" 404 -
# 127.0.0.1 - - [28/Jul/2021 20:44:59] "POST /prediction HTTP/1.1" 404 -
# 127.0.0.1 - - [28/Jul/2021 20:45:26] "POST /prediction HTTP/1.1" 404 -
#  * Detected change in '/opt/app-root/src/metrobus-repairs-nlp-workshop/wsgi.py', reloading
#  * Restarting with stat
#  * Debugger is active!
#  * Debugger PIN: 144-592-317
# 2021-07-28 20:47:13.810325: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-07-28 20:47:15.151694: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-07-28 20:47:15.151863: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2021-07-28 20:47:15.151885: W tensorflow/stream_executor/cuda/cuda_driver.cc:326] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-07-28 20:47:15.151914: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (jupyterhub-nb-adrezni): /proc/driver/nvidia/version does not exist
# 2021-07-28 20:47:15.152099: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-07-28 20:47:15.154115: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-07-28 20:47:15.213793: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2021-07-28 20:47:15.225254: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2500000000 Hz
# Epoch 1/2
# 23/23 [==============================] - 1s 32ms/step - loss: 0.9429 - accuracy: 0.5838 - val_loss: 0.5089 - val_accuracy: 0.9250
# Epoch 2/2
# 23/23 [==============================] - 0s 5ms/step - loss: 0.3894 - accuracy: 0.9773 - val_loss: 0.2223 - val_accuracy: 0.9750
# 7/7 [==============================] - 0s 895us/step - loss: 0.2042 - accuracy: 0.9800
#  * Detected change in '/opt/app-root/src/metrobus-repairs-nlp-workshop/prediction.py', reloading
#  * Restarting with stat
#  * Debugger is active!
#  * Debugger PIN: 144-592-317
# 2021-07-28 20:47:35.646920: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-07-28 20:47:37.004585: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-07-28 20:47:37.004766: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2021-07-28 20:47:37.004788: W tensorflow/stream_executor/cuda/cuda_driver.cc:326] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-07-28 20:47:37.004818: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (jupyterhub-nb-adrezni): /proc/driver/nvidia/version does not exist
# 2021-07-28 20:47:37.005006: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-07-28 20:47:37.006671: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-07-28 20:47:37.066782: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2021-07-28 20:47:37.078246: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2500000000 Hz
# Epoch 1/2

# %% [markdown]
# Once the models have been loaded, our server is ready to take requests. Leave this notebook running,and open `04_MBR_test_application.ipynb`.
