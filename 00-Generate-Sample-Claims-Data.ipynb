# %% [markdown]
# ## Data Generation
#
# In order to train a model to classify faults with metrobuses, we must first get our hands on some data. In this notebook we take a small data set, containing only 100 samples, and use [Markovify](https://github.com/jsvine/markovify) to simulate a larger data set, based on the original samples.
#
# We obtained a small data set by asking our colleagues to describe issues they currently have or had in the past, with their vehicles.
#
# **Note: you do not need to run this notebook in order to execute the remainder of the workshop. This notebook is solely for data generation. We have already generated the data for you, and it can be found in the `/dataset` folder.**
#
# Let's take a look at that data:

# %%
import pandas as pd

# %%
pd.set_option('display.max_colwidth', None)
df = pd.read_csv('dataset/response.csv') 
df.sample(10)
# Out:
#                      Timestamp What is the main issue you're having   \
# 87   2021/03/05 2:24:33 AM CST                                 Other
# 26  2021/03/04 12:40:35 PM CST                                Brakes
# 2   2021/03/04 11:47:13 AM CST                                 Other
# 63   2021/03/04 2:01:06 PM CST                                 Other
# 27  2021/03/04 12:41:26 PM CST                                 Other
# 40   2021/03/04 1:19:20 PM CST                               Starter
# 33  2021/03/04 12:51:04 PM CST                               Starter
# 67   2021/03/04 2:04:59 PM CST                               Starter
# 56   2021/03/04 1:54:16 PM CST                                 Other
# 44   2021/03/04 1:21:03 PM CST                                Brakes
#
#    Please pick one of these three symptoms:  \
# 87                                      NaN
# 26                                      NaN
# 2                                       NaN
# 63                                      NaN
# 27                                      NaN
# 40                        Car doesn't start
# 33                        Car doesn't start
# 67                        Car doesn't start
# 56                                      NaN
# 44                                      NaN
#
#                                                                                                                                                                                Please pretend you're a customer. In the space below tell us in your own words what's going wrong with your car:  \
# 87                                                                                                                                                                                                                                                                                          NaN
# 26                                                                                                                                                                                                                                                                                          NaN
# 2                                                                                                                                                                                                                                                                                           NaN
# 63                                                                                                                                                                                                                                                                                          NaN
# 27                                                                                                                                                                                                                                                                                          NaN
# 40                                                                                                                                                                               I turn the key and hear funny sounds but nothing happens.  Cannot get the car to turn over.  Please help ASAP!
# 33  Sometimes the car doesn't start and it seems like the battery is dead, but I have replaced the battery three times over the past year, so I think maybe either I'm buying defective batteries or something about the car is wrecking perfectly good batteries that should be lasting years.
# 67                                                                                                                                                                                                                             It won't start and doesn't respond when trying to jump start it.
# 56                                                                                                                                                                                                                                                                                          NaN
# 44                                                                                                                                                                                                                                                                                          NaN
#
#    Please pick one of these three symptoms:.1  \
# 87                                        NaN
# 26      Car brakes, but then brakes disengage
# 2                                         NaN
# 63                                        NaN
# 27                                        NaN
# 40                                        NaN
# 33                                        NaN
# 67                                        NaN
# 56                                        NaN
# 44                   Car makes grinding noise
#
#                                                                                   Please pretend you're a customer. In the space below tell us in your own words what's going wrong with your car:.1  \
# 87                                                                                                                                                                                               NaN
# 26  When coming to a stop at a stop light, I press on the brake and the car comes to a complete stop, but then starts rolling again even if I keep my foot firmly pressing down on the brake pedal.
# 2                                                                                                                                                                                                NaN
# 63                                                                                                                                                                                               NaN
# 27                                                                                                                                                                                               NaN
# 40                                                                                                                                                                                               NaN
# 33                                                                                                                                                                                               NaN
# 67                                                                                                                                                                                               NaN
# 56                                                                                                                                                                                               NaN
# 44                                                                     It is more squealing or screeching sounds than grinding.  Plus it seems it takes more force to stop and sometimes very bumpy.
#
#                                                                                                                                                                                                 Please pretend you're a customer. In the space below tell us in your own words what's going wrong with your car:.2
# 87                                                                                                                                                                                                                                                            When I drive, I feel like the car is leaning on left
# 26                                                                                                                                                                                                                                                                                                             NaN
# 2                                                                                                                                                                                                                                                                             I can't open the damn door to my car
# 63                                                                                                                                                                                                                                                               When turning, the car is making a clicking noise.
# 27                                                                                                                                                                                                                                                                                                 AC doesn't work
# 40                                                                                                                                                                                                                                                                                                             NaN
# 33                                                                                                                                                                                                                                                                                                             NaN
# 67                                                                                                                                                                                                                                                                                                             NaN
# 56  When I put the car in reverse, the hatchback latch opens so that the backup camera can engage. That's all good. But sometimes, the latch stays permanently opened while I'm driving and when I stop and park, I cannot open the hatchback due to the latch being stuck in the open position (but not engaged).
# 44                                                                                                                                                                                                                                                                                                             NaN

# %% [markdown]
# As you can see, the data contains a range of information including, the time the error was recorded, and the type of issue, as well as a description of the problem. The information we are really interested in is the type of issue, and the description - let's go ahead and process this data, extracting only the info we need!

# %%
df = df.fillna('')
df['response']=df.iloc[:,3]+df.iloc[:,5]+df.iloc[:,6]
df['issue'] = df.iloc[:,1]
df['symptom'] = df.iloc[:,2] + df.iloc[:,4]
subset = df.iloc[:,-3:]
subset.sample(10)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                  response  \
# 34                                                                                                                                                                                                                                                                  I press down on the brake pedal all the way to the floor, and the car does slow, but it takes a long time to come to a complete stop.
# 1                                                                                                                                                                                                                                                                                                                         super frustrating every time I start my car it just stops again, what is wrong!
# 16  I came out from work at the end of the day and the car would not start. I have a keyless start system and when I step on the brake and pushed the button, the lights would come one and the car would make a click click clicking sound but would not start. I'm not sure if it is the battery since the lights and radio worked but it definitely was not starting. Just that odd clicking noise....
# 45                                                                                                                                                                                                                                                                                                         Starter makes clicking noise, won't start the engine unless you hit the starter with a hammer.
# 92                                                                                  The car won't turn on, but it won't turn off either.  I'm on the side of the road, the lights, radio, electronic door locks, etc are all working fine, but the car won't shift out of park.  When I hit the start button to turn everything off, everything stays on.  It won't go, but it kind of won't stop either.
# 41                                                                                                                                                                                                                                                                                                                                    I'm hearing a noise and feeling a vibration when I turn the wheel.
# 30                                                                                                                                                                                                                                                                                                                                           Customer states breaks make a terrible sound when stopping.
# 3                                                                                                                                                                                                                                                                                                                                                                      I turn the key and nothing happens
# 33                                                                                                            Sometimes the car doesn't start and it seems like the battery is dead, but I have replaced the battery three times over the past year, so I think maybe either I'm buying defective batteries or something about the car is wrecking perfectly good batteries that should be lasting years.
# 17                                                                                                                                                                                                                                                            It was really cold out and I could not get the emergency brake to disengage. When I tried to drive, the car made horrible grinding noises.
#
#       issue                            symptom
# 34   Brakes  Car doesn't stop in timely manner
# 1   Starter              Car starts then stops
# 16  Starter                  Car doesn't start
# 45  Starter                  Car doesn't start
# 92    Other
# 41    Other
# 30   Brakes           Car makes grinding noise
# 3   Starter                  Car doesn't start
# 33  Starter                  Car doesn't start
# 17   Brakes           Car makes grinding noise

# %% [markdown]
# This looks much nicer! Let's explore our data:

# %%
subset.issue.unique()
# Out:
# array(['Brakes', 'Starter', 'Other'], dtype=object)

# %% [markdown]
# We only have 3 categories of issue - 'Brakes', 'Starter' and 'Other'.
#
# How much data do we have?

# %%
subset.shape
# Out:
# (109, 3)

# %%
subset['issue'].value_counts()
# Out:
# Other      56
# Brakes     28
# Starter    25
# Name: issue, dtype: int64

# %% [markdown]
# Only 109 rows - That's not likely to be enough to train a successful categorization model.
#
# Most of the data falls into the 'other' category.

# %% [markdown]
# In the rest of this notebook, we use Markovify to generate more data for each class of issue. Markovify is a Markov Chain generator, and we are going to use it to simulate more responses for each type of issue.
#
# First we install markovify, which is in our `nb-requirements.txt` file:

# %%
# !pip install -r nb-requirements.txt
# Out:
# Requirement already satisfied: markovify==0.9.3 in /opt/app-root/lib/python3.8/site-packages (from -r nb-requirements.txt (line 1)) (0.9.3)
# Requirement already satisfied: tensorflow==2.7 in /opt/app-root/lib/python3.8/site-packages (from -r nb-requirements.txt (line 2)) (2.7.0)
# Requirement already satisfied: scikit-learn==0.24.1 in /opt/app-root/lib/python3.8/site-packages (from -r nb-requirements.txt (line 3)) (0.24.1)
# Requirement already satisfied: numpy==1.19.2 in /opt/app-root/lib/python3.8/site-packages (from -r nb-requirements.txt (line 4)) (1.19.2)
# Requirement already satisfied: pandas==1.2.4 in /opt/app-root/lib/python3.8/site-packages (from -r nb-requirements.txt (line 5)) (1.2.4)
# Requirement already satisfied: keras==2.* in /opt/app-root/lib/python3.8/site-packages (from -r nb-requirements.txt (line 6)) (2.7.0)
# Requirement already satisfied: unidecode in /opt/app-root/lib/python3.8/site-packages (from markovify==0.9.3->-r nb-requirements.txt (line 1)) (1.3.3)
# Requirement already satisfied: tensorflow-estimator<2.8,~=2.7.0rc0 in /opt/app-root/lib/python3.8/site-packages (from tensorflow==2.7->-r nb-requirements.txt (line 2)) (2.7.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.21.0 in /opt/app-root/lib/python3.8/site-packages (from tensorflow==2.7->-r nb-requirements.txt (line 2)) (0.23.1)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/app-root/lib/python3.8/site-packages (from tensorflow==2.7->-r nb-requirements.txt (line 2)) (1.12.1)
# Requirement already satisfied: flatbuffers<3.0,>=1.12 in /opt/app-root/lib/python3.8/site-packages (from tensorflow==2.7->-r nb-requirements.txt (line 2)) (1.12)
# Requirement already satisfied: protobuf>=3.9.2 in /opt/app-root/lib/python3.8/site-packages (from tensorflow==2.7->-r nb-requirements.txt (line 2)) (3.19.3)
# Requirement already satisfied: wheel<1.0,>=0.32.0 in /opt/app-root/lib/python3.8/site-packages (from tensorflow==2.7->-r nb-requirements.txt (line 2)) (0.37.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/app-root/lib/python3.8/site-packages (from tensorflow==2.7->-r nb-requirements.txt (line 2)) (3.3.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/app-root/lib/python3.8/site-packages (from tensorflow==2.7->-r nb-requirements.txt (line 2)) (0.2.0)
# Requirement already satisfied: six>=1.12.0 in /opt/app-root/lib/python3.8/site-packages (from tensorflow==2.7->-r nb-requirements.txt (line 2)) (1.15.0)
# Requirement already satisfied: tensorboard~=2.6 in /opt/app-root/lib/python3.8/site-packages (from tensorflow==2.7->-r nb-requirements.txt (line 2)) (2.6.0)
# Requirement already satisfied: h5py>=2.9.0 in /opt/app-root/lib/python3.8/site-packages (from tensorflow==2.7->-r nb-requirements.txt (line 2)) (2.10.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/app-root/lib/python3.8/site-packages (from tensorflow==2.7->-r nb-requirements.txt (line 2)) (1.32.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /opt/app-root/lib/python3.8/site-packages (from tensorflow==2.7->-r nb-requirements.txt (line 2)) (1.1.2)
# Requirement already satisfied: libclang>=9.0.1 in /opt/app-root/lib/python3.8/site-packages (from tensorflow==2.7->-r nb-requirements.txt (line 2)) (12.0.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/app-root/lib/python3.8/site-packages (from tensorflow==2.7->-r nb-requirements.txt (line 2)) (1.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/app-root/lib/python3.8/site-packages (from tensorflow==2.7->-r nb-requirements.txt (line 2)) (3.7.4.3)
# Requirement already satisfied: gast<0.5.0,>=0.2.1 in /opt/app-root/lib/python3.8/site-packages (from tensorflow==2.7->-r nb-requirements.txt (line 2)) (0.3.3)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/app-root/lib/python3.8/site-packages (from tensorflow==2.7->-r nb-requirements.txt (line 2)) (1.6.3)
# Requirement already satisfied: absl-py>=0.4.0 in /opt/app-root/lib/python3.8/site-packages (from tensorflow==2.7->-r nb-requirements.txt (line 2)) (0.15.0)
# Requirement already satisfied: joblib>=0.11 in /opt/app-root/lib/python3.8/site-packages (from scikit-learn==0.24.1->-r nb-requirements.txt (line 3)) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/app-root/lib/python3.8/site-packages (from scikit-learn==0.24.1->-r nb-requirements.txt (line 3)) (3.0.0)
# Requirement already satisfied: scipy>=0.19.1 in /opt/app-root/lib/python3.8/site-packages (from scikit-learn==0.24.1->-r nb-requirements.txt (line 3)) (1.6.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/app-root/lib/python3.8/site-packages (from pandas==1.2.4->-r nb-requirements.txt (line 5)) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /opt/app-root/lib/python3.8/site-packages (from pandas==1.2.4->-r nb-requirements.txt (line 5)) (2021.3)
# Requirement already satisfied: markdown>=2.6.8 in /opt/app-root/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow==2.7->-r nb-requirements.txt (line 2)) (3.3.6)
# Requirement already satisfied: setuptools>=41.0.0 in /opt/app-root/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow==2.7->-r nb-requirements.txt (line 2)) (60.9.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /opt/app-root/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow==2.7->-r nb-requirements.txt (line 2)) (2.0.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /opt/app-root/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow==2.7->-r nb-requirements.txt (line 2)) (0.4.6)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /opt/app-root/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow==2.7->-r nb-requirements.txt (line 2)) (1.35.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /opt/app-root/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow==2.7->-r nb-requirements.txt (line 2)) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /opt/app-root/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow==2.7->-r nb-requirements.txt (line 2)) (1.8.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/app-root/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow==2.7->-r nb-requirements.txt (line 2)) (2.27.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/app-root/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow==2.7->-r nb-requirements.txt (line 2)) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /opt/app-root/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow==2.7->-r nb-requirements.txt (line 2)) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/app-root/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow==2.7->-r nb-requirements.txt (line 2)) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/app-root/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow==2.7->-r nb-requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /opt/app-root/lib/python3.8/site-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow==2.7->-r nb-requirements.txt (line 2)) (4.10.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/app-root/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow==2.7->-r nb-requirements.txt (line 2)) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /opt/app-root/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow==2.7->-r nb-requirements.txt (line 2)) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/app-root/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow==2.7->-r nb-requirements.txt (line 2)) (2.0.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/app-root/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow==2.7->-r nb-requirements.txt (line 2)) (1.26.8)
# Requirement already satisfied: zipp>=0.5 in /opt/app-root/lib/python3.8/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.6->tensorflow==2.7->-r nb-requirements.txt (line 2)) (3.7.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/app-root/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow==2.7->-r nb-requirements.txt (line 2)) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/app-root/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow==2.7->-r nb-requirements.txt (line 2)) (3.1.1)

# %%
import markovify
import csv

# %%
def train_markov_type(data, issue):
    return markovify.Text(data[data["issue"] == issue].response, retain_original=False, state_size=2)

#Function takes one of the 'issue' models and creates a randomly-generated sentence of length up to 100 characters.  
def make_sentence(model, length=100):
    return model.make_short_sentence(length, max_overlap_ratio = .7, max_overlap_total=15)

#built models
other_model = train_markov_type(subset, "Other")
brakes_model = train_markov_type(subset, "Brakes")
starter_model = train_markov_type(subset, "Starter")

# %% [markdown]
# We can combine these models with relative weights:

# %%
import numpy

def generate_cases(models, weights=None):
    if weights is None:
        weights = [1] * len(models)
    
    choices = [] # Array of tuples of weight and models
    
    total_weight = float(sum(weights))
    
    for i in range(len(weights)):
        choices.append((float(sum(weights[0:i+1])) / total_weight, models[i]))
    
    # Return a tuple of model and category that are randomly selected by given weights.
    def choose_model():
        r = numpy.random.uniform()
        for (model_weight, model) in choices:
            if r <= model_weight:
                return model
        return choices[-1][1]


    while True:
        local_model = choose_model() 
        # local_model[0]) is the markovify model, local_model[1] is the category
        yield make_sentence(local_model[0]), local_model[1]

# %% [markdown]
# We can now use this code to generate new sentences:

# %%
import numpy as np

generated_cases = generate_cases([(other_model,'other'), (brakes_model,'brakes'), (starter_model,'starter')], [14,7,7])

# Tuples with sentence and category
sentence_tuples = [next(generated_cases)  for i in range(1000)]  # create 200 sentence/category tuples

# %%
sentence_tuples
# Out:
# [('This is the third one, and I hear a grinding noise as I drive.', 'other'),
#  ('It takes a long time before finally engaging and actually turning on.',
#   'starter'),
#  ("If I knew what the problem was, I wouldn't be on some website, I'd be fixing it!!",
#   'other'),
#  ('My battery keeps dying.', 'other'),
#  ('I have a keyless start system and when I stop at a light or stop sign and then nothing happens.',
#   'starter'),
#  ('I can hear the starter with a hammer.', 'starter'),
#  ('Front right corner is dented from a collision.', 'other'),
#  ('The battery is getting old so my range is a bit short these days.',
#   'other'),
#  ("AC doesn't work", 'other'),
#  ('Brake pads appear less than ¼ inch thick', 'brakes'),
#  ('I try to start the engine doesn’t power up', 'starter'),
#  ('When I tried to drive, the car', 'brakes'),
#  ('It sputters for a very long time to start, and if I push the key and nothing happens',
#   'starter'),
#  ('Just that odd clicking noise....', 'starter'),
#  ('My battery keeps dying.', 'other'),
#  ('When I turn the key and nothing happens', 'starter'),
#  ("If I knew what the problem was, I wouldn't be on some website, I'd be fixing it!!",
#   'other'),
#  ('Car won’t stop quickly', 'brakes'),
#  ('Car makes a squeaky noise when stopping.', 'brakes'),
#  ('68F', 'other'),
#  ('the flux capacitor is misfiring and I hear a grinding noise as I drive.',
#   'other'),
#  ('I have the car is now a pile of ashes.', 'other'),
#  ('Brake pedal engagement varies, sometimes hard sometimes soft', 'other'),
#  ('Please help ASAP!', 'starter'),
#  ('A/C is working, but is not blowing out cold air', 'other'),
#  ("The car won't start!", 'other'),
#  ('Metallic scraping or grinding noise and brakes disengage', 'brakes'),
#  ('My battery keeps dying.', 'other'),
#  ('I think my alignment is bad.', 'other'),
#  ('My car does not turn over', 'starter'),
#  ('Metallic scraping or grinding noise and brakes disengage', 'brakes'),
#  ('Not so much a grinding noise, more like a piercing shriek of anguish',
#   'brakes'),
#  ("My air conditioning is whistling whenever it's turned on low.", 'other'),
#  ("My window won't roll up.", 'other'),
#  ("the flux capacitor is misfiring and I can't get up to 88 MPH", 'other'),
#  ('My car does not turn over.', 'starter'),
#  ('Front right corner is dented from a collision.', 'other'),
#  ('Usefulness is vanishing...', 'other'),
#  ('Just that odd clicking noise....', 'starter'),
#  ('I turn the key in it makes a sputtering noise and does not turn over',
#   'starter'),
#  ('Plus it seems it takes a long time to stop.', 'brakes'),
#  ('I have some noise when i drive it above 60 mph.', 'other'),
#  ('It then takes several clicks on the fuel line, and apparently it came loose while driving.',
#   'other'),
#  ('My tire keeps going flat.', 'other'),
#  ('I have a problem with my blinker fluid.', 'other'),
#  ("My air conditioning doesn't seem to be working.", 'other'),
#  ('And the brake pedal', 'brakes'),
#  ('I think my alignment is bad.', 'other'),
#  ("There isn't an immediate response.", 'other'),
#  ('Everything seems to be something related to the left.', 'other'),
#  ('my car does not stop', 'brakes'),
#  ("the flux capacitor is misfiring and I can't get up to 88 MPH", 'other'),
#  ("There isn't an immediate response.", 'other'),
#  ('Car creates whistle sound each time I start it', 'starter'),
#  ('I have the car evaluated.', 'other'),
#  ('The windshield has a growing crack in it.', 'other'),
#  ('I turn the key and hear funny sounds but nothing happens.', 'starter'),
#  ("That's all good.", 'other'),
#  ('Car takes too long to stop the car.', 'brakes'),
#  ('my lights do not work', 'other'),
#  ('I think my alignment is bad.', 'other'),
#  ('Steering wheel shakes uncontrollably when I accelerate above 60 mph',
#   'other'),
#  ('There a loud knocking sound coming from the front of the car.', 'other'),
#  ('Car takes too long to stop and sometimes very bumpy.', 'brakes'),
#  ('car makes grinding noise and brakes disengage', 'brakes'),
#  ("Car doesn't always start when it's low on blinker fluid", 'starter'),
#  ("Car dies when I stop at a light or stop sign and then won't start again.",
#   'starter'),
#  ('Brake pedal engagement varies, sometimes hard sometimes soft', 'other'),
#  ('my lights do not work', 'other'),
#  ('car makes grinding noise and brakes disengage', 'brakes'),
#  ('I can hear the starter with a hammer.', 'starter'),
#  ('Sometimes the car would make a click click clicking sound - maybe a dead battery?',
#   'starter'),
#  ('my lights do not work', 'other'),
#  ("It won't start and it seems like the battery three times before the car doesnt start.",
#   'starter'),
#  ('Car creates whistle sound each time I try to start it.', 'starter'),
#  ("My window won't roll up.", 'other'),
#  ('Dashboard computer reboots when traveling above 80mph', 'other'),
#  ('My car is leaning on left', 'other'),
#  ("AC doesn't work", 'other'),
#  ('I keep driving past my driveway because the car does not stop', 'brakes'),
#  ('When I try to start the car, it spits and sputters for a few seconds and then nothing happens.',
#   'starter'),
#  ('It makes a grinding sound for a very long time before finally engaging and actually turning on.',
#   'starter'),
#  ('This is the third one, and I hear a rattling noise when I go over a bump.',
#   'other'),
#  ("I'm on the side of the car. t only has two modes -- full blast heat or full blast cooling.",
#   'other'),
#  ('Sometimes the car would not start.', 'starter'),
#  ('Squealing sound', 'brakes'),
#  ('my lights do not work', 'other'),
#  ('Parking brake doesn’t return once released', 'brakes'),
#  ('Car makes a squeaky noise when breaking.', 'brakes'),
#  ("My air conditioning is whistling whenever it's turned on low.", 'other'),
#  ("The gas door won't open.", 'other'),
#  ('It seems like I have to press the brake pedal.', 'brakes'),
#  ('My car sounds like its 20 years old when I try to stop when I press the brakes',
#   'brakes'),
#  ("It won't go, but it kind of won't stop either.", 'other'),
#  ('Usefulness is vanishing...', 'other'),
#  ("I'm on the fuel line, and apparently it came loose while driving.",
#   'other'),
#  ('It makes a grinding sound for a very long time before finally engaging and actually turning on.',
#   'starter'),
#  ("sometimes, it won't go up at all!", 'other'),
#  ("Car doesn't always start when it's low on blinker fluid", 'starter'),
#  ('The left rear window only rolls down but does not roll back up.', 'other'),
#  ('Car takes too long to stop and sometimes very bumpy.', 'brakes'),
#  ("It then takes several clicks on the side of the vents doesn't feel any colder than the outside air.",
#   'other'),
#  ('The left rear window only rolls down but does not feel secure.', 'other'),
#  ("That's all good.", 'other'),
#  ('I have some noise when i drive it above 60 mph.', 'other'),
#  ("When I'm taking a left turn, the steering wheel shakes when running at speed",
#   'other'),
#  ('Brake pedal engagement varies, sometimes hard sometimes soft', 'other'),
#  ('I can hear the starter with a hammer.', 'starter'),
#  ("I can't put gas in my steering wheel.", 'other'),
#  ('The paint on the menu to return to my car is now a pile of ashes.',
#   'other'),
#  ('Please help ASAP!', 'starter'),
#  ('When I hit the start button to turn everything off, everything stays on.',
#   'other'),
#  ('My battery keeps dying.', 'other'),
#  ('My car is behaving very weird.', 'other'),
#  ('It seems like I have to brake the car', 'brakes'),
#  ("the privacy glass between my driver and my seating area doesn't work well.",
#   'other'),
#  ('Usefulness is vanishing...', 'other'),
#  ("That's all good.", 'other'),
#  ('I have the button pushed in and the air coming out of the car.', 'other'),
#  ('A/C is working, but is not blowing out cold air', 'other'),
#  ('Brake pedal vibrates', 'brakes'),
#  ('Squealing sound', 'brakes'),
#  ('The car is behaving very weird.', 'other'),
#  ('I can hear the starter firing but the car to turn over.', 'starter'),
#  ('I turn the key and nothing happens', 'starter'),
#  ('Brake pedal engagement varies, sometimes hard sometimes soft', 'other'),
#  ('Alternator is faulty', 'starter'),
#  ('I think my alignment is bad.', 'other'),
#  ("My window won't roll up.", 'other'),
#  ("I can't drive that way, always these bullshitty new technologies...",
#   'starter'),
#  ('Just that odd clicking noise....', 'starter'),
#  ("sometimes, it won't turn off either.", 'other'),
#  ('Spongy brake pedal.', 'brakes'),
#  ('Exhaust has a lot of black smoke and acrid smell.', 'other'),
#  ('When it rains, the car does not work, you pull the window up, it goes all the way up and then down.',
#   'other'),
#  ('My car does not turn over', 'starter'),
#  ('Car won’t stop quickly', 'brakes'),
#  ('Just that odd clicking noise....', 'starter'),
#  ('Fuel economy has gotten very bad.', 'other'),
#  ('Front right corner is dented from a collision.', 'other'),
#  ('Have to cycle the ignition button at least twice before my car starts.',
#   'starter'),
#  ('The car make some squeaking noises when I press the brakes disengage.',
#   'brakes'),
#  ("When I'm taking a left turn, the steering wheel shakes when running at speed",
#   'other'),
#  ('Brake pads appear less than ¼ inch thick', 'brakes'),
#  ('The HVAC system is broken in the front.', 'other'),
#  ('Customer states breaks make a terrible sound when stopping.', 'brakes'),
#  ('It then takes several clicks on the passenger front side is having issues and does not feel secure.',
#   'other'),
#  ('Fuel economy has gotten very bad.', 'other'),
#  ("AC doesn't work well.", 'other'),
#  ('Blind Spot Monitoring system will randomly be disabled.', 'other'),
#  ('Usefulness is vanishing...', 'other'),
#  ('Car makes a squeaky noise when breaking.', 'brakes'),
#  ('I turn the wheel.', 'other'),
#  ('Aaarrrggghhh!!!!', 'other'),
#  ('my lights do not work', 'other'),
#  ('Car dies when I step on the the fourth time.', 'starter'),
#  ('Spongy brake pedal.', 'brakes'),
#  ('Squealing sound', 'brakes'),
#  ('windshield wipers', 'other'),
#  ("The car won't start!", 'other'),
#  ('Car takes too long to stop', 'brakes'),
#  ("When I'm taking a left turn, the steering wheel shakes uncontrollably when I go over a bump.",
#   'other'),
#  ('The oil change has been performed.', 'other'),
#  ('Parking brake doesn’t return once released', 'brakes'),
#  ('But the car slides under braking and specially slips when driving over painted lines on the road',
#   'other'),
#  ('car makes grinding noise', 'brakes'),
#  ('Parking brake doesn’t return once released', 'brakes'),
#  ('When coming to a complete stop.', 'brakes'),
#  ("Car creates whistle sound each time I start my car but it doesn't work.",
#   'starter'),
#  ('I have the button pushed in and the fan is running full blast.', 'other'),
#  ('Car does not start.', 'starter'),
#  ('I press down on the brake pedal', 'brakes'),
#  ("There isn't an immediate response.", 'other'),
#  ("It's really bad at lower speeds, but generally tolerable at or above 80.",
#   'other'),
#  ('I press the brake pedal.', 'brakes'),
#  ('The car make some squeaking noises when stopping.', 'brakes'),
#  ("sometimes, it won't turn on, but it kind of won't stop either.", 'other'),
#  ('Aaarrrggghhh!!!!', 'other'),
#  ('I have some noise when I push the gas peddle.', 'other'),
#  ('My car drifts when driving over painted lines on the side of the car.',
#   'other'),
#  ('Shuttering when accelerating', 'other'),
#  ("Where's the place, where I need to insert my key to start the ignition?",
#   'starter'),
#  ('Brake pads appear less than ¼ inch thick', 'brakes'),
#  ('my lights do not work', 'other'),
#  ('That is all', 'other'),
#  ("I'm hearing a noise and feeling a vibration when I push the gas peddle.",
#   'other'),
#  ('Not so much a grinding noise, more like a piercing shriek of anguish',
#   'brakes'),
#  ('I turn the key in it makes a sputtering noise and does not turn over.',
#   'starter'),
#  ('Aaarrrggghhh!!!!', 'other'),
#  ('I keep my foot firmly pressing down on the brake pedal.', 'brakes'),
#  ("I'm not sure if it is the battery since the lights would come one and the car to turn over.",
#   'starter'),
#  ("I'm hearing a noise and feeling a vibration when I manually check it, it is fine.",
#   'other'),
#  ('I try to start the engine doesn’t power up', 'starter'),
#  ('Squealing sound', 'brakes'),
#  ('Squealing sound', 'brakes'),
#  ("Car doesn't always start when it's low on blinker fluid", 'starter'),
#  ("I'm on the left door is scratched.", 'other'),
#  ('When I turn the key and nothing happens', 'starter'),
#  ('The paint on the menu to return to my car if the control says, eg.',
#   'other'),
#  ('When coming to a complete stop.', 'brakes'),
#  ('Dashboard computer reboots when traveling above 80mph', 'other'),
#  ("I have a keyless start system and when I stop at a light or stop sign and then won't start again.",
#   'starter'),
#  ('I came out from work at the end of the day and the car to turn over.',
#   'starter'),
#  ("I can't put gas in my car", 'other'),
#  ('Brake pedal vibrates', 'brakes'),
#  ('Brake pedal vibrates', 'brakes'),
#  ("Where's the place, where I need to insert my key to start it.", 'starter'),
#  ("I'm hearing a noise and feeling a vibration when I bought the car.",
#   'other'),
#  ('Car does not turn over.', 'starter'),
#  ('It is very unpleasant.', 'brakes'),
#  ('I try to start the car, it spits and sputters for a while and never turns over.',
#   'starter'),
#  ("There's slack in my car is very slow to get moving and there's a horrible grinding noise as I drive.",
#   'other'),
#  ('The brake squeak and any time the slightest pressure is applied to the brake pedal.',
#   'brakes'),
#  ('When I try to start the engine doesn’t power up', 'starter'),
#  ('It makes a grinding noise too.', 'starter'),
#  ('Steering wheel shakes when running at speed', 'other'),
#  ("I can't get up to 88 MPH", 'other'),
#  ('I turn the wheel.', 'other'),
#  ('Not so much a grinding noise and brakes disengage', 'brakes'),
#  ('It is very unpleasant.', 'brakes'),
#  ('Brake pedal vibrates or feels unsteady as you press down', 'brakes'),
#  ("Car doesn't always start when it's low on blinker fluid", 'starter'),
#  ('Metallic scraping or grinding noise when breaking.', 'brakes'),
#  ('The seat belt itself on the road', 'other'),
#  ('Please help ASAP!', 'starter'),
#  ('Fuel economy has gotten very bad.', 'other'),
#  ('The left rear window only rolls down but does not feel secure.', 'other'),
#  ('I press the brakes a bit harder than I normally would.', 'brakes'),
#  ('There a loud knocking sound coming from the front of the car.', 'other'),
#  ('Steering wheel shakes when running at speed', 'other'),
#  ('Steering wheel shakes uncontrollably when I accelerate above 60 mph',
#   'other'),
#  ('Spongy brake pedal.', 'brakes'),
#  ("That's all good.", 'other'),
#  ('Car makes a grinding noise, more like a piercing shriek of anguish',
#   'brakes'),
#  ('The car is now a pile of ashes.', 'other'),
#  ('Just that odd clicking noise....', 'starter'),
#  ('My tire keeps going flat.', 'other'),
#  ("sometimes, it won't go up at all!", 'other'),
#  ('The driver side window auto function does not roll back up.', 'other'),
#  ("Where's the place, where I need to insert my key to start it.", 'starter'),
#  ('The car pulls to the air bag or seat belt.', 'other'),
#  ('When I put the car evaluated.', 'other'),
#  ('When I try to start it.', 'starter'),
#  ('car makes grinding noise and brakes disengage', 'brakes'),
#  ('Shuttering when accelerating', 'other'),
#  ('I think my car', 'other'),
#  ('I was working on the road', 'other'),
#  ('When I put the car is leaning on left', 'other'),
#  ("I can't drive that way, always these bullshitty new technologies...",
#   'starter'),
#  ('Car takes too long to stop', 'brakes'),
#  ('my lights do not work', 'other'),
#  ('When I try to start it.', 'starter'),
#  ("Car doesn't always start when it's low on blinker fluid", 'starter'),
#  ('A/C is working, but is not blowing out cold air', 'other'),
#  ('Car makes a grinding noise, more like a piercing shriek of anguish',
#   'brakes'),
#  ('68F', 'other'),
#  ('Sometimes the car is wrecking perfectly good batteries that should be lasting years.',
#   'starter'),
#  ("AC doesn't work", 'other'),
#  ('It sputters for a few seconds and then nothing happens.', 'starter'),
#  ('I tried starting my car but it definitely was not starting.', 'starter'),
#  ("I can't get up to 88 MPH", 'other'),
#  ('I was working on the menu to return to my previous display which is very unsafe.',
#   'other'),
#  ('I turn the key and hear funny sounds but nothing happens.', 'starter'),
#  ('It is very unpleasant.', 'brakes'),
#  ('Car dies when I step on the the fourth time.', 'starter'),
#  ('I hear a rattling noise when I open my rear trunk', 'other'),
#  ('I have the car is now a pile of ashes.', 'other'),
#  ('I press the brakes', 'brakes'),
#  ('The oil change has been performed.', 'other'),
#  ("Rear right tail light is on, which means I need to have the car won't start!",
#   'other'),
#  ('It is very unpleasant.', 'brakes'),
#  ('Car makes a grinding noise and brakes disengage', 'brakes'),
#  ('I can hear the starter with a hammer.', 'starter'),
#  ('There is a bit short these days.', 'other'),
#  ('Car does not turn over.', 'starter'),
#  ('The driver side window auto function does not feel secure.', 'other'),
#  ("There's slack in my steering wheel.", 'other'),
#  ('Car takes too long to stop and sometimes very bumpy.', 'brakes'),
#  ('Squealing sound', 'brakes'),
#  ('Brake pedal vibrates or feels unsteady as you press down', 'brakes'),
#  ('Metallic scraping or grinding noise', 'brakes'),
#  ('Spongy brake pedal.', 'brakes'),
#  ('Just that odd clicking noise....', 'starter'),
#  ('I think my alignment is bad.', 'other'),
#  ('When I turn the key and nothing happens', 'starter'),
#  ('Leak of a clear, cloudy, oil like substance in the back of the car.',
#   'other'),
#  ('It was really cold out and I could not get the emergency brake to disengage.',
#   'brakes'),
#  ('My car is making a clicking noise.', 'other'),
#  ('I turn the key in the ignition, I just get a clicking sound but would not start.',
#   'starter'),
#  ('Parking brake doesn’t return once released', 'brakes'),
#  ('When I try to start it.', 'starter'),
#  ("Everything seems to be working ok, but that sound wasn't there when I push the gas peddle.",
#   'other'),
#  ("My air conditioning is whistling whenever it's turned on low.", 'other'),
#  ("the privacy glass between my driver and my seating area doesn't work",
#   'other'),
#  ("I'm having an issue with fuel injection sensor or pressure.", 'other'),
#  ('My tire keeps going flat.', 'other'),
#  ("The car won't start!", 'other'),
#  ('Plus it seems it takes a long time to stop.', 'brakes'),
#  ('Spongy brake pedal.', 'brakes'),
#  ('Please help ASAP!', 'starter'),
#  ('Car makes a grinding noise when stopping.', 'brakes'),
#  ('I have a problem with my blinker fluid.', 'other'),
#  ("When I'm taking a left turn, the steering wheel shudders and I don't get it.",
#   'other'),
#  ('Brake pads appear less than ¼ inch thick', 'brakes'),
#  ('Car takes too long to stop the car.', 'brakes'),
#  ('When I put the car does not roll back up.', 'other'),
#  ('my car does slow, but it takes more force to stop', 'brakes'),
#  ('I turn the key and hear funny sounds but nothing happens.', 'starter'),
#  ('Not so much a grinding noise', 'brakes'),
#  ("I can't drive that way, always these bullshitty new technologies...",
#   'starter'),
#  ('My car is leaning on left', 'other'),
#  ('68F', 'other'),
#  ("This is the third one, and I don't get it.", 'other'),
#  ("I don't get it.", 'other'),
#  ('It seems like I have to press the brakes a bit harder than I normally would.',
#   'brakes'),
#  ("I can't drive that way, always these bullshitty new technologies...",
#   'starter'),
#  ('Usefulness is vanishing...', 'other'),
#  ('Not so much a grinding noise when stopping.', 'brakes'),
#  ("Car doesn't always start when it's low on blinker fluid", 'starter'),
#  ('When I tried to drive, the car refuses to stop and sometimes very bumpy.',
#   'brakes'),
#  ('Just that odd clicking noise....', 'starter'),
#  ('Rear right tail light is out.', 'other'),
#  ("I'm having an issue with fuel injection sensor or pressure.", 'other'),
#  ("sometimes, it won't go up at all!", 'other'),
#  ('Spongy brake pedal.', 'brakes'),
#  ('My car sounds like its 20 years old when I try to stop when I press the brakes',
#   'brakes'),
#  ('That is all', 'other'),
#  ('I was working on the menu to return to my car is now a pile of ashes.',
#   'other'),
#  ("The car won't start!", 'other'),
#  ('The windshield has a lot of black smoke and acrid smell.', 'other'),
#  ("The car won't shift out of the vents doesn't feel any colder than the outside air.",
#   'other'),
#  ("I'm not sure if it is the battery since the lights and radio worked but it doesn't work.",
#   'starter'),
#  ('My car drifts when driving over painted lines on the menu to return to my car',
#   'other'),
#  ('The windshield has a lot of black smoke and acrid smell.', 'other'),
#  ('My car makes a sputtering noise and does not start.', 'starter'),
#  ('Shuttering when accelerating', 'other'),
#  ('Exhaust has a growing crack in it.', 'other'),
#  ('I have some noise when i drive it above 60 mph', 'other'),
#  ('Car creates whistle sound each time I start it', 'starter'),
#  ("My back seat seatbelt won't lock.", 'other'),
#  ('my brakes make a deep grinding metal sound', 'brakes'),
#  ("That's all good.", 'other'),
#  ('Car makes a squeaky noise when stopping.', 'brakes'),
#  ('My car does not turn over', 'starter'),
#  ('I can hear the starter with a hammer.', 'starter'),
#  ("It won't go, but it won't go up at all!", 'other'),
#  ('It makes clunking noises when I turn the wheel.', 'other'),
#  ('Car makes a squeaky noise when breaking.', 'brakes'),
#  ('The oil change has been performed.', 'other'),
#  ("I have replaced the battery since the lights and radio worked but it doesn't work.",
#   'starter'),
#  ("My window won't roll up.", 'other'),
#  ('Rear right tail light is out.', 'other'),
#  ('I think my alignment is bad.', 'other'),
#  ('I turn the key in the ignition, I just get a clicking sound but would not start.',
#   'starter'),
#  ("The car won't turn off either.", 'other'),
#  ('While driving I hear lot of grinding and scraping noises when stopping.',
#   'brakes'),
#  ('There a loud knocking sound coming from the front of the car.', 'other'),
#  ('My car makes a weird whirring sound every time I start my car it just stops again, what is wrong!',
#   'starter'),
#  ('The battery is getting old so my range is a lag when I bought the car.',
#   'other'),
#  ("The car won't shift out of park.", 'other'),
#  ('My car does not start.', 'starter'),
#  ('My car does not start.', 'starter'),
#  ('Exhaust has a lot of black smoke and acrid smell.', 'other'),
#  ('My car is making a clicking noise.', 'other'),
#  ("It won't go, but it kind of won't stop either.", 'other'),
#  ("It won't go, but it kind of won't stop either.", 'other'),
#  ('I have some noise when i drive it above 60 mph.', 'other'),
#  ('Aaarrrggghhh!!!!', 'other'),
#  ("I can't drive that way, always these bullshitty new technologies...",
#   'starter'),
#  ('Fuel economy has gotten very bad.', 'other'),
#  ('the privacy glass between my driver and my tires seem to be wearing down at different rates.',
#   'other'),
#  ('The driver side window auto function does not feel secure.', 'other'),
#  ('It makes a weird whirring sound every time I start it', 'starter'),
#  ('There is a light that came on that looks to be something related to the left.',
#   'other'),
#  ('My battery keeps dying.', 'other'),
#  ("It won't go, but it won't turn off either.", 'other'),
#  ("My window won't roll up.", 'other'),
#  ('My car makes a grinding sound for a while and never turns over.',
#   'starter'),
#  ('My car is now a pile of ashes.', 'other'),
#  ("The gas door won't open, and I'm all out of gas.", 'other'),
#  ("My window won't roll up.", 'other'),
#  ("This is the third one, and I can't put gas in my steering wheel.", 'other'),
#  ("When turning, the car is very slow to get moving and there's a horrible grinding noise as I drive.",
#   'other'),
#  ('Car does not start.', 'starter'),
#  ('my car does not stop', 'brakes'),
#  ('Car dies when I stop at a light or stop sign and then nothing happens.',
#   'starter'),
#  ('Shuttering when accelerating', 'other'),
#  ("The car won't turn on, but it won't turn off either.", 'other'),
#  ("Car doesn't always start when it's low on blinker fluid", 'starter'),
#  ('Blind Spot Monitoring system will randomly be disabled.', 'other'),
#  ("My air conditioning doesn't seem to be working.", 'other'),
#  ('Then I have to brake the car made horrible grinding noises.', 'brakes'),
#  ('The air conditioner only blows cold sometimes.', 'other'),
#  ('Everything seems to be wearing down at different rates.', 'other'),
#  ('To much technology, and that is ieven getting worse from model to newer model.',
#   'other'),
#  ('Car makes a squeaky noise when stopping.', 'brakes'),
#  ('Sometimes when I press the brakes', 'brakes'),
#  ('Alternator is faulty', 'starter'),
#  ("My air conditioning is whistling whenever it's turned on low.", 'other'),
#  ('Brake pedal engagement varies, sometimes hard sometimes soft', 'other'),
#  ('Brake pedal vibrates or feels unsteady as you press down', 'brakes'),
#  ('It is very unpleasant.', 'brakes'),
#  ("It won't go, but it won't go up at all!", 'other'),
#  ('That is all', 'other'),
#  ('Just that odd clicking noise....', 'starter'),
#  ('It makes clunking noises when I go over a bump.', 'other'),
#  ('windshield wipers', 'other'),
#  ("If I knew what the problem was, I wouldn't be on some website, I'd be fixing it!!",
#   'other'),
#  ('The windshield has a lot of black smoke and acrid smell.', 'other'),
#  ("Car doesn't always start when it's low on blinker fluid", 'starter'),
#  ('Dashboard computer reboots when traveling above 80mph', 'other'),
#  ('Aaarrrggghhh!!!!', 'other'),
#  ("It won't start and doesn't respond when trying to jump start it.",
#   'starter'),
#  ('I can hear the starter with a hammer.', 'starter'),
#  ('I can hear the starter with a hammer.', 'starter'),
#  ('car makes grinding noise when breaking.', 'brakes'),
#  ('Car makes a squeaky noise when stopping.', 'brakes'),
#  ("I can't get up to 88 MPH", 'other'),
#  ('car makes grinding noise', 'brakes'),
#  ('I can hear the starter firing but the engine doesn’t power up', 'starter'),
#  ('It was really cold out and I could not get the emergency brake to disengage.',
#   'brakes'),
#  ('The driver side window auto function does not roll back up.', 'other'),
#  ('Blind Spot Monitoring system will randomly be disabled.', 'other'),
#  ('My car sounds like its 20 years old when I press the brake pedal all the way to the brake pedal',
#   'brakes'),
#  ("Car doesn't always start when it's low on blinker fluid", 'starter'),
#  ("I can't put gas in my car is leaning on left", 'other'),
#  ('My car is leaning on left', 'other'),
#  ('I hear a grinding noise coming from somewhere in the car.', 'other'),
#  ('I tried starting my car it just stops again, what is wrong!', 'starter'),
#  ('68F', 'other'),
#  ("There isn't an immediate response.", 'other'),
#  ("the flux capacitor is misfiring and I can't get up to 88 MPH", 'other'),
#  ('my lights do not work', 'other'),
#  ('I turn the key in it makes a sputtering noise and does not start.',
#   'starter'),
#  ('The car make some squeaking noises when stopping.', 'brakes'),
#  ('Brake pads appear less than ¼ inch thick', 'brakes'),
#  ('windshield wipers', 'other'),
#  ('When it rains, the car in reverse, the hatchback latch opens so that the backup camera can engage.',
#   'other'),
#  ('I think my alignment is bad.', 'other'),
#  ('I hear a grinding noise coming from somewhere in the car.', 'other'),
#  ('I try to start it.', 'starter'),
#  ('The air conditioner only blows cold sometimes.', 'other'),
#  ('Metallic scraping or grinding noise and brakes disengage', 'brakes'),
#  ('I tried starting my car it just stops again, what is wrong!', 'starter'),
#  ('Everything seems to be something related to the left.', 'other'),
#  ('I try to start the engine doesn’t power up', 'starter'),
#  ('But the car is behaving very weird.', 'other'),
#  ('I try to start it.', 'starter'),
#  ('Alternator is faulty', 'starter'),
#  ('The HVAC system is broken in the front.', 'other'),
#  ('Leak of a clear, cloudy, oil like substance in the front.', 'other'),
#  ('windshield wipers', 'other'),
#  ('It makes a weird whirring sound every time I start my car it just stops again, what is wrong!',
#   'starter'),
#  ('I was working on the road', 'other'),
#  ('A/C is working, but is not blowing out cold air', 'other'),
#  ("I'm hearing a noise and feeling a vibration when I open my rear trunk",
#   'other'),
#  ('The battery is getting old so my range is a lag when I open my rear trunk',
#   'other'),
#  ('Car creates whistle sound each time I start my car starts.', 'starter'),
#  ('I tried starting my car but it definitely was not starting.', 'starter'),
#  ("Car doesn't always start when it's low on blinker fluid", 'starter'),
#  ('When I put the car does not roll back up.', 'other'),
#  ('My car is behaving very weird.', 'other'),
#  ("The car won't turn off either.", 'other'),
#  ('Car makes a squeaky noise when breaking.', 'brakes'),
#  ('Steering wheel shakes uncontrollably when I push the gas peddle.', 'other'),
#  ('My car is leaning on left', 'other'),
#  ("My car drifts when driving it and my seating area doesn't work well.",
#   'other'),
#  ('Customer states breaks make noises and also take more time to stop.',
#   'brakes'),
#  ('Car won’t stop quickly', 'brakes'),
#  ('There is a bit short these days.', 'other'),
#  ('Customer states breaks make a terrible sound when stopping.', 'brakes'),
#  ('Everything seems to be wearing down at different rates.', 'other'),
#  ('A/C is working, but is not blowing out cold air', 'other'),
#  ('I was working on the road', 'other'),
#  ('That is all', 'other'),
#  ('When I try to start the car, it spits and sputters for a while and never turns over.',
#   'starter'),
#  ('My car does not start.', 'starter'),
#  ('Brake pads appear less than ¼ inch thick', 'brakes'),
#  ('It sputters for a while and never turns over.', 'starter'),
#  ("I'm on the left door is scratched.", 'other'),
#  ('I have some noise when i drive it above 60 mph', 'other'),
#  ('Exhaust has a lot of black smoke and acrid smell.', 'other'),
#  ('Just that odd clicking noise....', 'starter'),
#  ('Leak of a clear, cloudy, oil like substance in the car.', 'other'),
#  ("Car doesn't always start when it's low on blinker fluid", 'starter'),
#  ('Car makes a squeaky noise when breaking.', 'brakes'),
#  ('I try to start the ignition?', 'starter'),
#  ('I turn the key, nothing happens.', 'other'),
#  ('My tire keeps going flat.', 'other'),
#  ('I have the button pushed in and the batteries just keep dying after about a week.',
#   'other'),
#  ("It won't go, but it kind of won't stop either.", 'other'),
#  ('My car is behaving very weird.', 'other'),
#  ("That's all good.", 'other'),
#  ('It then takes several clicks on the freeway.', 'other'),
#  ('My car does not turn over.', 'starter'),
#  ('That is all', 'other'),
#  ('And the brake pedal vibrates or feels unsteady as you press down on the brake and the car',
#   'brakes'),
#  ('I have a keyless start system and when I stop at a light or stop sign and then nothing happens.',
#   'starter'),
#  ('The oil change has been performed.', 'other'),
#  ('The car make some squeaking noises when stopping.', 'brakes'),
#  ('Front right corner is dented from a collision.', 'other'),
#  ('Fuel economy has gotten very bad.', 'other'),
#  ('Not so much a grinding noise and brakes disengage', 'brakes'),
#  ("It's really bad at lower speeds, but generally tolerable at or above 80.",
#   'other'),
#  ('The pedal feels squishy and pulses when I try to brake the car refuses to stop the car.',
#   'brakes'),
#  ('When I put the car evaluated.', 'other'),
#  ('The other 3 tires report normally.', 'other'),
#  ('The car pulls to the left.', 'other'),
#  ('Car dies when I step on the the fourth time.', 'starter'),
#  ('My car sounds like its 20 years old when I push hard on the brakes.',
#   'brakes'),
#  ('It makes clunking noises when I turn the radio and asking me if I know where the All Spark is hidden',
#   'other'),
#  ('I tried starting my car it just stops again, what is wrong!', 'starter'),
#  ('It seems like I have to brake the car refuses to stop when I try to stop and sometimes very bumpy.',
#   'brakes'),
#  ('To much technology, and that is ieven getting worse from model to newer model.',
#   'other'),
#  ('Not so much a grinding noise, more like a piercing shriek of anguish',
#   'brakes'),
#  ('windshield wipers', 'other'),
#  ("There isn't an immediate response.", 'other'),
#  ("My air conditioning is whistling whenever it's turned on low.", 'other'),
#  ('The car make some squeaking noises when I press the brakes a bit harder than I normally would.',
#   'brakes'),
#  ('The air conditioner only blows cold sometimes.', 'other'),
#  ('But the car in reverse, the hatchback latch opens so that the backup camera can engage.',
#   'other'),
#  ('The windshield has a lot of black smoke and acrid smell.', 'other'),
#  ("It won't go, but it kind of won't stop either.", 'other'),
#  ('My car is now a pile of ashes.', 'other'),
#  ('I press down on the brake pedal.', 'brakes'),
#  ('Alternator is faulty', 'starter'),
#  ("AC doesn't work well.", 'other'),
#  ('Blind Spot Monitoring system will randomly be disabled.', 'other'),
#  ('Sometimes the car is wrecking perfectly good batteries that should be lasting years.',
#   'starter'),
#  ('It sputters for a very long time before finally engaging and actually turning on.',
#   'starter'),
#  ('Sometimes the car to turn over.', 'starter'),
#  ('The other 3 tires report normally.', 'other'),
#  ('My car does not turn over', 'starter'),
#  ('I have some noise when I accelerate above 60 mph', 'other'),
#  ('my brakes make a terrible sound when stopping.', 'brakes'),
#  ('car makes grinding noise', 'brakes'),
#  ('super frustrating every time I start it', 'starter'),
#  ('Dashboard computer reboots when traveling above 80mph', 'other'),
#  ("It won't start again.", 'starter'),
#  ('The pedal feels squishy and pulses when I try to stop', 'brakes'),
#  ('Please help ASAP!', 'starter'),
#  ('My battery keeps dying.', 'other'),
#  ('My car is now a pile of ashes.', 'other'),
#  ('my car does not stop', 'brakes'),
#  ('If I try to set it at anything other than MAX COOL, it defaults to full blast cooling.',
#   'other'),
#  ('Metallic scraping or grinding noise when stopping.', 'brakes'),
#  ('I came out from work at the end of the day and the car doesnt start.',
#   'starter'),
#  ('When I put the car in reverse, the hatchback latch opens so that the backup camera can engage.',
#   'other'),
#  ('It sputters for a few seconds and then nothing happens.', 'starter'),
#  ("If I knew what the problem was, I wouldn't be on some website, I'd be fixing it!!",
#   'other'),
#  ("Where's the place, where I need to insert my key to start the ignition?",
#   'starter'),
#  ("The car won't shift out of the car.", 'other'),
#  ('Just that odd clicking noise....', 'starter'),
#  ('While driving I hear lot of grinding and scraping noises when stopping.',
#   'brakes'),
#  ('I have a problem with my blinker fluid.', 'other'),
#  ("I'm having an issue with fuel injection sensor or pressure.", 'other'),
#  ('A/C is working, but is not blowing out cold air', 'other'),
#  ('When I tried to drive, the car comes to a complete stop.', 'brakes'),
#  ('I turn the key and nothing happens', 'starter'),
#  ('Car creates whistle sound each time I try to start the ignition?',
#   'starter'),
#  ('car makes grinding noise', 'brakes'),
#  ('I press the brakes disengage.', 'brakes'),
#  ('Car dies when I stop at a light or stop sign and then nothing happens.',
#   'starter'),
#  ("Car doesn't always start when it's low on blinker fluid", 'starter'),
#  ('There is a bit short these days.', 'other'),
#  ("I can't open the damn door to my car if the control says, eg.", 'other'),
#  ('That is all', 'other'),
#  ('Plus it seems it takes a long time to stop.', 'brakes'),
#  ('Parking brake doesn’t return once released', 'brakes'),
#  ('While driving I hear lot of grinding and scraping noises when stopping.',
#   'brakes'),
#  ('It makes a grinding noise too.', 'starter'),
#  ("My window won't roll up.", 'other'),
#  ("My window won't roll up.", 'other'),
#  ('The other 3 tires report normally.', 'other'),
#  ('The warning indicator light is out.', 'other'),
#  ("Starter makes clicking noise, won't start again.", 'starter'),
#  ('Plus it seems it takes a long time to come to a complete stop.', 'brakes'),
#  ('It then takes several clicks on the side of the car.', 'other'),
#  ('I keep my foot firmly pressing down on the brake pedal.', 'brakes'),
#  ("That's all good.", 'other'),
#  ('The windshield has a growing crack in it.', 'other'),
#  ('It makes a weird whirring sound every time I start my car it just stops again, what is wrong!',
#   'starter'),
#  ('The driver side window auto function does not roll back up.', 'other'),
#  ("The car won't shift out of the vents doesn't feel any colder than the outside air.",
#   'other'),
#  ('Alternator is faulty', 'starter'),
#  ('windshield wipers', 'other'),
#  ("I'm on the left door is scratched.", 'other'),
#  ("I'm hearing a noise and feeling a vibration when I bought the car.",
#   'other'),
#  ("the flux capacitor is misfiring and I can't get up to 88 MPH", 'other'),
#  ("I can't drive that way, always these bullshitty new technologies...",
#   'starter'),
#  ("AC doesn't work well.", 'other'),
#  ('It makes clunking noises when I push the gas peddle.', 'other'),
#  ('My car sounds like its 20 years old when I try to stop and sometimes very bumpy.',
#   'brakes'),
#  ('Please help ASAP!', 'starter'),
#  ('If I try to set it at anything other than MAX COOL, it defaults to full blast cooling.',
#   'other'),
#  ('my lights do not work', 'other'),
#  ('Brake pedal vibrates or feels unsteady as you press down', 'brakes'),
#  ('Please help ASAP!', 'starter'),
#  ("My air conditioning is whistling whenever it's turned on low.", 'other'),
#  ('The brake squeak and any time the slightest pressure is applied to the floor, and the car',
#   'brakes'),
#  ('I have the button pushed in and the light comes on and the fan is running full blast.',
#   'other'),
#  ('Sometimes the car doesnt start.', 'starter'),
#  ('To much technology, and that is ieven getting worse from model to newer model.',
#   'other'),
#  ('Car does not turn over', 'starter'),
#  ("The HVAC system is broken in the back of the vents doesn't feel any colder than the outside air.",
#   'other'),
#  ("Car doesn't always start when it's low on blinker fluid", 'starter'),
#  ('Aaarrrggghhh!!!!', 'other'),
#  ('The HVAC system is broken in the front.', 'other'),
#  ('Brake pads appear less than ¼ inch thick', 'brakes'),
#  ("I don't know what more you want from me, I get into the car, turn the wheel.",
#   'other'),
#  ('It takes a long time to start, and if I push the key and nothing happens',
#   'starter'),
#  ("It won't go, but it won't go up at all!", 'other'),
#  ('The other 3 tires report normally.', 'other'),
#  ("sometimes, it won't turn off either.", 'other'),
#  ('My cars breaks make noises and also take more time to stop.', 'brakes'),
#  ("If I knew what the problem was, I wouldn't be on some website, I'd be fixing it!!",
#   'other'),
#  ("Car doesn't always start when it's low on blinker fluid", 'starter'),
#  ('Car dies when I step on the the fourth time.', 'starter'),
#  ('I turn the key in the ignition, I just get a clicking sound but would not start.',
#   'starter'),
#  ("sometimes, it won't go up at all!", 'other'),
#  ('Brake pedal vibrates or feels unsteady as you press down', 'brakes'),
#  ('My car does not turn over.', 'starter'),
#  ('Parking brake doesn’t return once released', 'brakes'),
#  ('My car is behaving very weird.', 'other'),
#  ('Car makes a squeaky noise when breaking.', 'brakes'),
#  ('When I tried to drive, the car refuses to stop when I press the brake pedal.',
#   'brakes'),
#  ('My battery keeps dying.', 'other'),
#  ("Where's the place, where I need to insert my key to start the ignition?",
#   'starter'),
#  ("I'm on the menu to return to my car is behaving very weird.", 'other'),
#  ('I can hear the starter with a hammer.', 'starter'),
#  ('Exhaust has a lot of black smoke and acrid smell.', 'other'),
#  ('And the brake and the car made horrible grinding noises.', 'brakes'),
#  ("I'm on the passenger front side is having issues and does not roll back up.",
#   'other'),
#  ('Brake pedal engagement varies, sometimes hard sometimes soft', 'other'),
#  ('The left rear window only rolls down but does not ever cool down and the air bag or seat belt.',
#   'other'),
#  ("It won't go, but it won't turn off either.", 'other'),
#  ('Blind Spot Monitoring system will randomly be disabled.', 'other'),
#  ("This must be a sensor issue on this tire, but I'm not sure.", 'other'),
#  ('It makes a grinding noise too.', 'starter'),
#  ('Brake pads appear less than ¼ inch thick', 'brakes'),
#  ("The car won't start!", 'other'),
#  ('my lights do not work', 'other'),
#  ('Spongy brake pedal.', 'brakes'),
#  ('Not so much a grinding noise, more like a piercing shriek of anguish',
#   'brakes'),
#  ('When turning, the car in reverse, the hatchback latch opens so that the backup camera can engage.',
#   'other'),
#  ('The left rear window only rolls down but does not ever cool down and the air coming out of gas.',
#   'other'),
#  ('I tried starting my car starts.', 'starter'),
#  ('Car does not start.', 'starter'),
#  ('Car does not turn over.', 'starter'),
#  ('Have to cycle the ignition button at least twice before my car it just stops again, what is wrong!',
#   'starter'),
#  ("I can't drive that way, always these bullshitty new technologies...",
#   'starter'),
#  ('I press the brakes disengage.', 'brakes'),
#  ('My car does not turn over', 'starter'),
#  ('My tire keeps going flat.', 'other'),
#  ('I was working on the fuel line, and apparently it came loose while driving.',
#   'other'),
#  ('68F', 'other'),
#  ("That's all good.", 'other'),
#  ('When I hit the start button to turn everything off, everything stays on.',
#   'other'),
#  ('Then I have to brake again.', 'brakes'),
#  ('My car makes a weird whirring sound every time I try to start the ignition?',
#   'starter'),
#  ("My back seat seatbelt won't lock.", 'other'),
#  ('Blind Spot Monitoring system will randomly be disabled.', 'other'),
#  ("This is the third one, and I can't put gas in my car", 'other'),
#  ('The car make some squeaking noises when I press on the brake and the car',
#   'brakes'),
#  ('There is a bit short these days.', 'other'),
#  ('Please help ASAP!', 'starter'),
#  ('my lights do not work', 'other'),
#  ('Have to cycle the ignition three times before the car doesnt start.',
#   'starter'),
#  ('When I turn the key and hear funny sounds but nothing happens.', 'starter'),
#  ("It sputters for a few seconds and then won't start the ignition?",
#   'starter'),
#  ('It makes a grinding noise too.', 'starter'),
#  ('Sometimes the car doesnt start.', 'starter'),
#  ('I have a problem with my blinker fluid.', 'other'),
#  ('The oil change light comes on and the fan is running full blast.', 'other'),
#  ('But the car in reverse, the hatchback latch opens so that the backup camera can engage.',
#   'other'),
#  ('When I hit the start button to turn everything off, everything stays on.',
#   'other'),
#  ("I can't drive that way, always these bullshitty new technologies...",
#   'starter'),
#  ('That is all', 'other'),
#  ("Where's the place, where I need to insert my key to start the ignition?",
#   'starter'),
#  ("The car won't start!", 'other'),
#  ("I'm hearing a noise and feeling a vibration when I manually check it, it is fine.",
#   'other'),
#  ('I turn the key in it makes a grinding noise too.', 'starter'),
#  ('Squealing sound', 'brakes'),
#  ('It makes a grinding noise too.', 'starter'),
#  ("My back seat seatbelt won't lock.", 'other'),
#  ('There is a bit short these days.', 'other'),
#  ("The car won't turn off either.", 'other'),
#  ("the flux capacitor is misfiring and I can't get up to 88 MPH", 'other'),
#  ("I don't know what more you want from me, I get into the car, turn the wheel.",
#   'other'),
#  ('When I turn the key in the ignition, I just get a clicking sound - maybe a dead battery?',
#   'starter'),
#  ("AC doesn't work well.", 'other'),
#  ('Car does not turn over', 'starter'),
#  ('68F', 'other'),
#  ('The car is now a pile of ashes.', 'other'),
#  ('I hear a grinding noise coming from somewhere in the car.', 'other'),
#  ('Car makes a squeaky noise when breaking.', 'brakes'),
#  ("My back seat seatbelt won't lock.", 'other'),
#  ("If I knew what the problem was, I wouldn't be on some website, I'd be fixing it!!",
#   'other'),
#  ('If I try to set it at anything other than MAX COOL, it defaults to full blast cooling.',
#   'other'),
#  ('I turn the key and nothing happens', 'starter'),
#  ("It won't start the ignition?", 'starter'),
#  ("the flux capacitor is misfiring and I can't put gas in my steering wheel.",
#   'other'),
#  ('Alternator is faulty', 'starter'),
#  ("Where's the place, where I need to insert my key to start the ignition?",
#   'starter'),
#  ("My window won't roll up.", 'other'),
#  ('Blind Spot Monitoring system will randomly be disabled.', 'other'),
#  ('There is a lag when I manually check it, it is fine.', 'other'),
#  ("The car won't shift out of the car.", 'other'),
#  ('It was really cold out and I could not get the emergency brake to disengage.',
#   'brakes'),
#  ("There isn't an immediate response.", 'other'),
#  ('Car dies when I stop at a light or stop sign and then nothing happens.',
#   'starter'),
#  ('The HVAC system is broken in the back of the car.', 'other'),
#  ('Squealing sound', 'brakes'),
#  ("If I knew what the problem was, I wouldn't be on some website, I'd be fixing it!!",
#   'other'),
#  ('I try to start the engine unless you hit the starter with a hammer.',
#   'starter'),
#  ("The car won't shift out of gas.", 'other'),
#  ("the privacy glass between my driver and my seating area doesn't work well.",
#   'other'),
#  ('Brake pedal engagement varies, sometimes hard sometimes soft', 'other'),
#  ('When I put the car is making a clicking noise.', 'other'),
#  ('Car takes too long to stop and sometimes very bumpy.', 'brakes'),
#  ("sometimes, it won't go up at all!", 'other'),
#  ("My air conditioning is whistling whenever it's turned on low.", 'other'),
#  ('When I turn the key and hear funny sounds but nothing happens.', 'starter'),
#  ('I think my car', 'other'),
#  ('I keep driving past my driveway because the car', 'brakes'),
#  ("It won't start again.", 'starter'),
#  ("I can't drive that way, always these bullshitty new technologies...",
#   'starter'),
#  ("That's all good.", 'other'),
#  ("the privacy glass between my driver and my seating area doesn't work",
#   'other'),
#  ('Car creates whistle sound each time I start my car but it definitely was not starting.',
#   'starter'),
#  ("I'm hearing a noise and feeling a vibration when I manually check it, it is fine.",
#   'other'),
#  ("I can't open the damn door to my previous display which is very unsafe.",
#   'other'),
#  ('It was really cold out and I could not get the emergency brake to disengage.',
#   'brakes'),
#  ("It won't start and doesn't respond when trying to jump start it.",
#   'starter'),
#  ('Then I have to brake again.', 'brakes'),
#  ('The steering wheel shakes uncontrollably when I open my rear trunk',
#   'other'),
#  ('Sometimes when I press the brakes a bit harder than I normally would.',
#   'brakes'),
#  ("My air conditioning doesn't seem to be something related to the left.",
#   'other'),
#  ("sometimes, it won't go up at all!", 'other'),
#  ('It seems like I have to press the brake pedal', 'brakes'),
#  ('My car is leaning on left', 'other'),
#  ('A/C is working, but is not blowing out cold air', 'other'),
#  ("I'm having an issue with fuel injection sensor or pressure.", 'other'),
#  ("I can't put gas in my car if the control says, eg.", 'other'),
#  ('Have to cycle the ignition button at least twice before my car it just stops again, what is wrong!',
#   'starter'),
#  ('I tried starting my car it just stops again, what is wrong!', 'starter'),
#  ('Car takes too long to stop when I press the brakes a bit harder than I normally would.',
#   'brakes'),
#  ('The other 3 tires report normally.', 'other'),
#  ('Please help ASAP!', 'starter'),
#  ('When I turn the key in it makes a grinding sound for a few seconds and then nothing happens.',
#   'starter'),
#  ('It sputters for a while and never turns over.', 'starter'),
#  ('Sometimes the car starts on the the fourth time.', 'starter'),
#  ('super frustrating every time I start it', 'starter'),
#  ("If I knew what the problem was, I wouldn't be on some website, I'd be fixing it!!",
#   'other'),
#  ("The gas door won't open.", 'other'),
#  ('The windshield has a lot of black smoke and acrid smell.', 'other'),
#  ('Metallic scraping or grinding noise and brakes disengage', 'brakes'),
#  ('While driving I hear lot of grinding and scraping noises when stopping.',
#   'brakes'),
#  ('My car makes a sputtering noise and does not turn over', 'starter'),
#  ("I'm on the freeway.", 'other'),
#  ('I press the brake pedal.', 'brakes'),
#  ('Spongy brake pedal.', 'brakes'),
#  ('The brake squeak and any time the slightest pressure is applied to the brake pedal.',
#   'brakes'),
#  ("When I'm taking a left turn, the steering wheel shudders and I can't put gas in my steering wheel.",
#   'other'),
#  ("It won't start the engine unless you hit the starter with a hammer.",
#   'starter'),
#  ('Brake pedal vibrates', 'brakes'),
#  ("The car won't start!", 'other'),
#  ('Please help ASAP!', 'starter'),
#  ("I'm on the freeway.", 'other'),
#  ("The gas door won't open.", 'other'),
#  ('Customer states breaks make a squeaking noise whenever I try to stop',
#   'brakes'),
#  ("sometimes, it won't go up at all!", 'other'),
#  ("That's all good.", 'other'),
#  ("This is the third one, and I don't get it.", 'other'),
#  ('Aaarrrggghhh!!!!', 'other'),
#  ('It seems like I have to brake the car does not stop', 'brakes'),
#  ('Squealing sound', 'brakes'),
#  ('I press on the brake pedal.', 'brakes'),
#  ("AC doesn't work", 'other'),
#  ('The left rear window only rolls down but does not feel secure.', 'other'),
#  ('The driver side window auto function does not feel secure.', 'other'),
#  ('Brake pads appear less than ¼ inch thick', 'brakes'),
#  ('I try to start the engine unless you hit the starter with a hammer.',
#   'starter'),
#  ('I turn the key and nothing happens', 'starter'),
#  ('When I try to start it.', 'starter'),
#  ('68F', 'other'),
#  ('Alternator is faulty', 'starter'),
#  ('Cannot get the car would make a click click clicking sound - maybe a dead battery?',
#   'starter'),
#  ('The other 3 tires report normally.', 'other'),
#  ('Sometimes when I press the brakes a bit harder than I normally would.',
#   'brakes'),
#  ("AC doesn't work", 'other'),
#  ('Front right corner is dented from a collision.', 'other'),
#  ('It makes a sputtering noise and does not start.', 'starter'),
#  ("It won't start again.", 'starter'),
#  ('When I try to start the engine doesn’t power up', 'starter'),
#  ('The pedal feels squishy and pulses when I press the brakes', 'brakes'),
#  ('And the brake pedal', 'brakes'),
#  ('My tire keeps going flat.', 'other'),
#  ("the flux capacitor is misfiring and I can't put gas in my car", 'other'),
#  ('I have a problem with my blinker fluid.', 'other'),
#  ("When I'm taking a left turn, the steering wheel shakes when running at speed",
#   'other'),
#  ("The car won't turn off either.", 'other'),
#  ('Car does not turn over.', 'starter'),
#  ("I don't get it.", 'other'),
#  ('It is more squealing or screeching sounds than grinding.', 'brakes'),
#  ('I think my car', 'other'),
#  ('Car does not turn over', 'starter'),
#  ('When coming to a complete stop.', 'brakes'),
#  ('When I tried to drive, the car', 'brakes'),
#  ('Just that odd clicking noise....', 'starter'),
#  ("It's an intense upper body workout to stay in one lane on the freeway.",
#   'other'),
#  ('Spongy brake pedal.', 'brakes'),
#  ("This must be a sensor issue on this tire, but I'm not sure.", 'other'),
#  ("The car won't shift out of gas.", 'other'),
#  ('My car does not turn over', 'starter'),
#  ('Usefulness is vanishing...', 'other'),
#  ('Brake pedal vibrates', 'brakes'),
#  ('Car makes a grinding noise, more like a piercing shriek of anguish',
#   'brakes'),
#  ('I think my alignment is bad.', 'other'),
#  ('Car makes a grinding noise, more like a piercing shriek of anguish',
#   'brakes'),
#  ('My battery keeps dying.', 'other'),
#  ('Car dies when I step on the the fourth time.', 'starter'),
#  ('And the brake and the car does not stop', 'brakes'),
#  ('Brake pads appear less than ¼ inch thick', 'brakes'),
#  ('Car creates whistle sound each time I start it', 'starter'),
#  ('The car make some squeaking noises when stopping.', 'brakes'),
#  ('I can hear the starter firing but the car doesnt start.', 'starter'),
#  ('the flux capacitor is misfiring and I hear a rattling noise when i drive it above 60 mph',
#   'other'),
#  ('My car does not turn over.', 'starter'),
#  ('my lights do not work', 'other'),
#  ('Car makes a grinding noise, more like a piercing shriek of anguish',
#   'brakes'),
#  ('Squealing sound', 'brakes'),
#  ('The battery is getting old so my range is a lag when I push the gas peddle.',
#   'other'),
#  ('my car does slow, but it takes more force to stop when I press the brakes disengage.',
#   'brakes'),
#  ('The driver side window auto function does not roll back up.', 'other'),
#  ("There's slack in my car is behaving very weird.", 'other'),
#  ('It takes a long time to start, and if I push the key and hear funny sounds but nothing happens.',
#   'starter'),
#  ('my brakes make a deep grinding metal sound', 'brakes'),
#  ('It makes a grinding sound for a very long time before finally engaging and actually turning on.',
#   'starter'),
#  ('It makes a grinding noise too.', 'starter'),
#  ('The other 3 tires report normally.', 'other'),
#  ('Car does not turn over', 'starter'),
#  ('It seems like I have to brake the car made horrible grinding noises.',
#   'brakes'),
#  ("I don't get it.", 'other'),
#  ("Cannot get the car doesn't start and doesn't respond when trying to jump start it.",
#   'starter'),
#  ('Cannot get the car starts on the the fourth time.', 'starter'),
#  ("I can't put gas in my car", 'other'),
#  ('My car is leaning on left', 'other'),
#  ('Parking brake doesn’t return once released', 'brakes'),
#  ('I turn the key in the ignition, I just get a clicking sound - maybe a dead battery?',
#   'starter'),
#  ('68F', 'other'),
#  ('It makes a sputtering noise and does not turn over.', 'starter'),
#  ("When I put the car won't start!", 'other'),
#  ('My cars breaks make noises and also take more time to come to a complete stop.',
#   'brakes'),
#  ("Car doesn't always start when it's low on blinker fluid", 'starter'),
#  ('my car does not stop', 'brakes'),
#  ("The car won't shift out of park.", 'other'),
#  ('It makes a grinding noise too.', 'starter'),
#  ('I think my car is now a pile of ashes.', 'other'),
#  ('The left rear window only rolls down but does not feel secure.', 'other'),
#  ('The pedal feels squishy and pulses when I brake, after a few seconds, the brakes',
#   'brakes'),
#  ('68F', 'other'),
#  ('68F', 'other'),
#  ('When it rains, the car is very unsafe.', 'other'),
#  ('Parking brake doesn’t return once released', 'brakes'),
#  ('Customer states breaks make noises and also take more time to stop.',
#   'brakes'),
#  ('car makes grinding noise', 'brakes'),
#  ('I have some noise when I go over a bump.', 'other'),
#  ("I can't put gas in my car is very unsafe.", 'other'),
#  ('my lights do not work', 'other'),
#  ('I turn the key and nothing happens', 'starter'),
#  ('Alternator is faulty', 'starter'),
#  ('Car takes too long to stop when I brake, after a few seconds, the brakes',
#   'brakes'),
#  ('My battery keeps dying.', 'other'),
#  ('I have a problem with my blinker fluid.', 'other'),
#  ('The warning indicator light is out.', 'other'),
#  ("My window won't roll up.", 'other'),
#  ('When I turn the key in it makes a sputtering noise and does not turn over',
#   'starter'),
#  ('It was really cold out and I could not get the emergency brake to disengage.',
#   'brakes'),
#  ('Rear right tail light is out.', 'other'),
#  ('Metallic scraping or grinding noise and brakes disengage', 'brakes'),
#  ('The car make some squeaking noises when stopping.', 'brakes'),
#  ('The oil change has been performed.', 'other'),
#  ('Plus it seems it takes more force to stop', 'brakes'),
#  ('A/C is working, but is not blowing out cold air', 'other'),
#  ('I can hear the starter firing but the car would not start.', 'starter'),
#  ('I turn the key in the ignition, I just get a clicking sound - maybe a dead battery?',
#   'starter'),
#  ("There's slack in my car is leaning on left", 'other'),
#  ('Dashboard computer reboots when traveling above 80mph', 'other'),
#  ('Usefulness is vanishing...', 'other'),
#  ('I think my alignment is bad.', 'other'),
#  ('The left rear window only rolls down but does not feel secure.', 'other'),
#  ('There is a light that came on that looks to be something related to the left.',
#   'other'),
#  ("The gas door won't open.", 'other'),
#  ('Squealing sound', 'brakes'),
#  ('Front right corner is dented from a collision.', 'other'),
#  ('I hear a grinding noise as I drive.', 'other'),
#  ('My car drifts when driving it and my tires seem to be working.', 'other'),
#  ("It won't go, but it won't turn off either.", 'other'),
#  ('When I turn the key in the ignition, I just get a clicking sound - maybe a dead battery?',
#   'starter'),
#  ("My window won't roll up.", 'other'),
#  ('Aaarrrggghhh!!!!', 'other'),
#  ('Car creates whistle sound each time I start it', 'starter'),
#  ('I turn the key and nothing happens', 'starter'),
#  ('I have some noise when i drive it above 60 mph', 'other'),
#  ('The pedal feels squishy and pulses when I try to stop', 'brakes'),
#  ('Have to cycle the ignition button at least twice before my car it just stops again, what is wrong!',
#   'starter'),
#  ("It won't go, but it won't turn off either.", 'other'),
#  ('But the car is leaning on left', 'other'),
#  ('While driving I hear lot of grinding and scraping noises when stopping.',
#   'brakes'),
#  ('My car makes a grinding noise too.', 'starter'),
#  ('The windshield has a growing crack in it.', 'other'),
#  ('This is the third one, and I hear a rattling noise when i drive it above 60 mph',
#   'other'),
#  ('Dashboard computer reboots when traveling above 80mph', 'other'),
#  ('super frustrating every time I try to start it.', 'starter'),
#  ('It makes a sputtering noise and does not start.', 'starter'),
#  ('The pedal feels squishy and pulses when I press down on the brakes.',
#   'brakes'),
#  ("I'm not sure if it is the battery since the lights would come one and the car to turn over.",
#   'starter'),
#  ('There is a lag when I push the gas peddle.', 'other'),
#  ("sometimes, it won't turn on, but it won't go up at all!", 'other'),
#  ('There is a light that came on that looks to be working.', 'other'),
#  ('I have a problem with my blinker fluid.', 'other'),
#  ("There isn't an immediate response.", 'other'),
#  ('Car does not turn over.', 'starter'),
#  ('There is a lag when I manually check it, it is fine.', 'other'),
#  ('The car make some squeaking noises when I press down', 'brakes'),
#  ("I'm on the fuel line, and apparently it came loose while driving.",
#   'other'),
#  ('my brakes make a terrible sound when stopping.', 'brakes'),
#  ('Fuel economy has gotten very bad.', 'other'),
#  ('the flux capacitor is misfiring and I hear a rattling noise when I open my rear trunk',
#   'other'),
#  ("It won't go, but it kind of won't stop either.", 'other'),
#  ('A/C is working, but is not blowing out cold air', 'other'),
#  ("When turning, the car won't shift out of the vents doesn't feel any colder than the outside air.",
#   'other'),
#  ('I have to press the ignition button at least twice before my car starts.',
#   'starter'),
#  ('There is a bit short these days.', 'other'),
#  ("I'm having an issue with fuel injection sensor or pressure.", 'other'),
#  ("Where's the place, where I need to insert my key to start it.", 'starter'),
#  ('Car takes too long to stop when I push hard on the brakes.', 'brakes'),
#  ('The warning indicator light is out.', 'other'),
#  ('The car pulls to the left.', 'other'),
#  ('There is a bit short these days.', 'other'),
#  ("Starter makes clicking noise, won't start and doesn't respond when trying to jump start it.",
#   'starter'),
#  ('Brake pedal engagement varies, sometimes hard sometimes soft', 'other'),
#  ('Aaarrrggghhh!!!!', 'other'),
#  ('And the brake pedal.', 'brakes'),
#  ('Sometimes the car doesnt start.', 'starter'),
#  ('Alternator is faulty', 'starter'),
#  ('The brake squeak and any time the slightest pressure is applied to the floor, and the car',
#   'brakes'),
#  ("This is the third one, and I don't get it.", 'other'),
#  ('Car creates whistle sound each time I try to start the engine doesn’t power up',
#   'starter'),
#  ('windshield wipers', 'other'),
#  ('I think my alignment is bad.', 'other'),
#  ('I have a problem with my blinker fluid.', 'other'),
#  ('But the car is now a pile of ashes.', 'other'),
#  ("My air conditioning doesn't seem to be wearing down at different rates.",
#   'other'),
#  ('Plus it seems it takes more force to stop', 'brakes'),
#  ('A/C is working, but is not blowing out cold air', 'other'),
#  ('I press down', 'brakes'),
#  ("It won't go, but it kind of won't stop either.", 'other'),
#  ('Car makes a grinding noise', 'brakes'),
#  ('My tire keeps going flat.', 'other'),
#  ('Leak of a clear, cloudy, oil like substance in the front.', 'other'),
#  ('That is all', 'other'),
#  ('Brake pedal vibrates or feels unsteady as you press down', 'brakes'),
#  ('I turn the key and nothing happens', 'starter'),
#  ("But the car won't shift out of park.", 'other'),
#  ('Sometimes when I press the brakes disengage.', 'brakes'),
#  ('Not so much a grinding noise and brakes disengage', 'brakes'),
#  ('I try to start the ignition?', 'starter'),
#  ('It makes a sputtering noise and does not turn over', 'starter'),
#  ('Brake pads appear less than ¼ inch thick', 'brakes'),
#  ('It is very unpleasant.', 'brakes'),
#  ('I turn the key and nothing happens', 'starter'),
#  ('Brake pedal vibrates or feels unsteady as you press down', 'brakes'),
#  ('The windshield has a lot of black smoke and acrid smell.', 'other'),
#  ("I'm having an issue with fuel injection sensor or pressure.", 'other'),
#  ('I turn the key and hear funny sounds but nothing happens.', 'starter'),
#  ('my lights do not work', 'other'),
#  ("It's really bad at lower speeds, but generally tolerable at or above 80.",
#   'other'),
#  ('Car takes too long to stop the car.', 'brakes'),
#  ('Cannot get the car would not start.', 'starter'),
#  ('I can hear the starter with a hammer.', 'starter'),
#  ("My air conditioning is whistling whenever it's turned on low.", 'other'),
#  ('It seems like I have to press the brakes', 'brakes'),
#  ('My car drifts when driving it and my tires seem to be wearing down at different rates.',
#   'other'),
#  ('Car creates whistle sound each time I start my car starts.', 'starter'),
#  ('When I try to start the ignition?', 'starter'),
#  ('Car creates whistle sound each time I start it', 'starter'),
#  ('Car takes too long to stop', 'brakes'),
#  ('My car makes a sputtering noise and does not turn over', 'starter'),
#  ('Blind Spot Monitoring system will randomly be disabled.', 'other'),
#  ('My car is making a clicking noise.', 'other'),
#  ('Have to cycle the ignition button at least twice before my car but it definitely was not starting.',
#   'starter'),
#  ("Car doesn't always start when it's low on blinker fluid", 'starter'),
#  ('The steering wheel shakes when running at speed', 'other'),
#  ('The oil change light comes on after an oil change has been performed.',
#   'other'),
#  ("I'm having an issue with fuel injection sensor or pressure.", 'other'),
#  ("I'm hearing a noise and feeling a vibration when I push the gas peddle.",
#   'other'),
#  ('super frustrating every time I start my car starts.', 'starter'),
#  ('Sometimes the car to turn over.', 'starter')]

# %%
len(sentence_tuples)
# Out:
# 1000

# %% [markdown]
# We can save these new issues and responses to file, and we will use this file later to train our model.

# %%
# Write to csv file
with open('dataset/testdata1.csv', 'w') as file:
    writer = csv.writer(file, delimiter=',', lineterminator='\n')
    writer.writerows(sentence_tuples)

# %% [markdown]
# At this point we have created a new data set, and we can transform this data and train a classification model.
#
# Let's head to notebook [01-Create-Claims-Classification.ipynb](01-Create-Claims-Classification.ipynb), where we process the data and train a classifier.
